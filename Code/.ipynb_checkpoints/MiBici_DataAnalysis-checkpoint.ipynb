# %% [markdown]
# # MiBici: Data Retrival & Cleaning

# %% [markdown]
# The goal of this jupyter notebook is to collect and clean the datasets that'll be used for the exploratory data analysis and data visualizations of the MiBici biking-system.

# %% [markdown]
# # Import Libraries

# %%
# Web scraping libraries
import requests
import urllib.request
from bs4 import BeautifulSoup


# Downloading, moving and unzipping files
import webbrowser
from time import sleep
import shutil
import os
#from zipfile import ZipFile
import glob


# Reverse Geocode
#import geopandas as gpd
import geopy
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter


# DataFrame exploration and manipulation
import pandas as pd
import numpy as np
import datetime as dt
import re


# Data Visualizations
import matplotlib.pyplot as plt
import seaborn as sns
#sns.set_theme() # Apply the default theme

pd.set_option('display.max_columns', None)

# %% [markdown]
# # MiBici Data

# %% [markdown]
# [MiBici]("https://www.mibici.net/es/datos-abiertos/") is Guadalajara's public bike sharing system in the state of Jalisco, Mexico. Their open data set contains monthly data files with information each nike trip taken with the system.

# %% [markdown]
# ## Obtain MiBici Data Files

# %% [markdown]
# The code for obtaining the MiBici data files from their website is based on the code produced by Fausto De La Rosa Mañón for their analysis on the NYC Citibike dataset. The article for their analysis can be found on [Medium](https://medium.com/@fausto.manon/building-a-citibike-database-with-python-9849a59fb90c)
# and the code on [GitHub](https://github.com/fmanon/Citibike_Trip_Data/blob/master/code/01_Create_Database.ipynb).

# %% [markdown]
# Request access to the MiBici Open Data webpage. `<Response [200]>` indicates that the request is successful.

# %%
url = 'https://www.mibici.net/es/datos-abiertos/'
response = requests.get(url, headers={"User-Agent": "XY"})
response
# Out:
# <Response [200]>

# %% [markdown]
# Parse the webpage using BeautifulSoup. This is to determine what HTML tag is used to identify the data files.

# %%
soup = BeautifulSoup(response.text, 'xml')

# %% [markdown]
# The .csv files that we want are stored with an `/<a>` tag.

# %%
data_files = soup.find_all('a')

# %% [markdown]
# Edit the `data_files` variable to remove the non-data elements and the data files for 2022.

# %%
data_files = data_files[35:107]

# %%
data_files
# Out:
# [<a href="/site/assets/files/1022/datos_abiertos_2017_01.csv"><li>Enero</li></a>,
#  <a href="/site/assets/files/1111/datos_abiertos_2017_02.csv"><li>Febrero</li></a>,
#  <a href="/site/assets/files/1112/datos_abiertos_2017_03.csv"><li>Marzo</li></a>,
#  <a href="/site/assets/files/1115/datos_abiertos_2017_04-1.csv"><li>Abril</li></a>,
#  <a href="/site/assets/files/1116/datos_abiertos_2017_05.csv"><li>Mayo</li></a>,
#  <a href="/site/assets/files/1119/datos_abiertos_2017_06.csv"><li>Junio</li></a>,
#  <a href="/site/assets/files/1120/datos_abiertos_2017_07.csv"><li>Julio</li></a>,
#  <a href="/site/assets/files/1122/datos_abiertos_2017_08.csv"><li>Agosto</li></a>,
#  <a href="/site/assets/files/1123/datos_abiertos_2017_09.csv"><li>Septiembre</li></a>,
#  <a href="/site/assets/files/1124/datos_abiertos_2017_10.csv"><li>Octubre</li></a>,
#  <a href="/site/assets/files/1197/datos_abiertos_2017_11.csv"><li>Noviembre</li></a>,
#  <a href="/site/assets/files/1198/datos_abiertos_2017_12.csv"><li>Diciembre</li></a>,
#  <a href="/site/assets/files/1200/datos_abiertos_2018_01.csv"><li>Enero</li></a>,
#  <a href="/site/assets/files/1201/datos_abiertos_2018_02.csv"><li>Febrero</li></a>,
#  <a href="/site/assets/files/1202/datos_abiertos_2018_03.csv"><li>Marzo</li></a>,
#  <a href="/site/assets/files/1203/datos_abiertos_2018_04.csv"><li>Abril</li></a>,
#  <a href="/site/assets/files/1204/datos_abiertos_2018_05.csv"><li>Mayo</li></a>,
#  <a href="/site/assets/files/1205/datos_abiertos_2018_06.csv"><li>Junio</li></a>,
#  <a href="/site/assets/files/1206/datos_abiertos_2018_07.csv"><li>Julio</li></a>,
#  <a href="/site/assets/files/1207/datos_abiertos_2018_08.csv"><li>Agosto</li></a>,
#  <a href="/site/assets/files/1208/datos_abiertos_2018_09.csv"><li>Septiembre</li></a>,
#  <a href="/site/assets/files/1209/datos_abiertos_2018_10.csv"><li>Octubre</li></a>,
#  <a href="/site/assets/files/1210/datos_abiertos_2018_11.csv"><li>Noviembre</li></a>,
#  <a href="/site/assets/files/1211/datos_abiertos_2018_12.csv"><li>Diciembre</li></a>,
#  <a href="/site/assets/files/1214/datos_abiertos_2019_01.csv"><li>Enero</li></a>,
#  <a href="/site/assets/files/1217/datos_abiertos_2019_02.csv"><li>Febrero</li></a>,
#  <a href="/site/assets/files/1218/datos_abiertos_2019_03.csv"><li>Marzo</li></a>,
#  <a href="/site/assets/files/1219/datos_abiertos_2019_04.csv"><li>Abril</li></a>,
#  <a href="/site/assets/files/1220/datos_abiertos_2019_05.csv"><li>Mayo</li></a>,
#  <a href="/site/assets/files/1221/datos_abiertos_2019_06.csv"><li>Junio</li></a>,
#  <a href="/site/assets/files/1222/datos_abiertos_2019_07.csv"><li>Julio</li></a>,
#  <a href="/site/assets/files/1223/datos_abiertos_2019_08.csv"><li>Agosto</li></a>,
#  <a href="/site/assets/files/1224/datos_abiertos_2019_09.csv"><li>Septiembre</li></a>,
#  <a href="/site/assets/files/1225/datos_abiertos_2019_10.csv"><li>Octubre</li></a>,
#  <a href="/site/assets/files/1227/datos_abiertos_2019_11.csv"><li>Noviembre</li></a>,
#  <a href="/site/assets/files/1228/datos_abiertos_2019_12.csv"><li>Diciembre</li></a>,
#  <a href="/site/assets/files/1230/datos_abiertos_2020_01.csv"><li>Enero</li></a>,
#  <a href="/site/assets/files/1231/datos_abiertos_2020_02.csv"><li>Febrero</li></a>,
#  <a href="/site/assets/files/1232/datos_abiertos_2020_03.csv"><li>Marzo</li></a>,
#  <a href="/site/assets/files/1235/datos_abiertos_2020_04.csv"><li>Abril</li></a>,
#  <a href="/site/assets/files/1236/datos_abiertos_2020_05.csv"><li>Mayo</li></a>,
#  <a href="/site/assets/files/1237/datos_abiertos_2020_06.csv"><li>Junio</li></a>,
#  <a href="/site/assets/files/1238/datos_abiertos_2020_07.csv"><li>Julio</li></a>,
#  <a href="/site/assets/files/1239/datos_abiertos_2020_08.csv"><li>Agosto</li></a>,
#  <a href="/site/assets/files/1240/datos_abiertos_2020_09.csv"><li>Septiembre</li></a>,
#  <a href="/site/assets/files/1241/datos_abiertos_2020_10.csv"><li>Octubre</li></a>,
#  <a href="/site/assets/files/1317/datos_abiertos_2020_11.csv"><li>Noviembre</li></a>,
#  <a href="/site/assets/files/1318/datos_abiertos_2020_12.csv"><li>Diciembre</li></a>,
#  <a href="/site/assets/files/1320/datos_abiertos_2021_01.csv"><li>Enero</li></a>,
#  <a href="/site/assets/files/1323/datos_abiertos_2021_02.csv"><li>Febrero</li></a>,
#  <a href="/site/assets/files/1322/datos_abiertos_2021_03.csv"><li>Marzo</li></a>,
#  <a href="/site/assets/files/2129/datos_abiertos_2021_04.csv"><li>Abril</li></a>,
#  <a href="/site/assets/files/3292/datos_abiertos_2021_05.csv"><li>Mayo</li></a>,
#  <a href="/site/assets/files/4572/datos_abiertos_2021_06.csv"><li>Junio</li></a>,
#  <a href="/site/assets/files/5728/datos_abiertos_2021_07.csv"><li>Julio</li></a>,
#  <a href="/site/assets/files/7073/datos_abiertos_2021_08.csv"><li>Agosto</li></a>,
#  <a href="/site/assets/files/8461/datos_abiertos_2021_09.csv"><li>Septiembre</li></a>,
#  <a href="/site/assets/files/10088/datos_abiertos_2021_10.csv"><li>Octubre</li></a>,
#  <a href="/site/assets/files/11538/datos_abiertos_2021_11.csv"><li>Noviembre</li></a>,
#  <a href="/site/assets/files/12780/datos_abiertos_2021_12.csv"><li>Diciembre</li></a>,
#  <a href="/site/assets/files/14797/datos_abiertos_2022_01.csv"><li>Enero</li></a>,
#  <a href="/site/assets/files/16831/datos_abiertos_2022_02.csv"><li>Febrero</li></a>,
#  <a href="/site/assets/files/19034/datos_abiertos_2022_03.csv"><li>Marzo</li></a>,
#  <a href="/site/assets/files/20338/datos_abiertos_2022_04.csv"><li>Abril</li></a>,
#  <a href="/site/assets/files/21842/datos_abiertos_2022_05.csv"><li>Mayo</li></a>,
#  <a href="/site/assets/files/23473/datos_abiertos_2022_06.csv"><li>Junio</li></a>,
#  <a href="/site/assets/files/25235/datos_abiertos_2022_07.csv"><li>Julio</li></a>,
#  <a href="/site/assets/files/27484/datos_abiertos_2022_08.csv"><li>Agosto</li></a>,
#  <a href="/site/assets/files/29663/datos_abiertos_2022_09.csv"><li>Septiembre</li></a>,
#  <a href="/site/assets/files/31507/datos_abiertos_2022_10.csv"><li>Octubre</li></a>,
#  <a href="/site/assets/files/33115/datos_abiertos_2022_11.csv"><li>Noviembre</li></a>,
#  <a href="/site/assets/files/1118/nomenclatura_2022_11.csv"><li>Nomenclatura de estaciones</li></a>]

# %% [markdown]
# Edit the `data_files` variable to get the data file name address.

# %%
def get_file_names(data_list):
    list = []
    for index in range(len(data_list)):
        list.append(data_list[index].attrs.get('href'))
    return list

# %%
data_files = get_file_names(data_files)

# %%
data_files
# Out:
# ['/site/assets/files/1022/datos_abiertos_2017_01.csv',
#  '/site/assets/files/1111/datos_abiertos_2017_02.csv',
#  '/site/assets/files/1112/datos_abiertos_2017_03.csv',
#  '/site/assets/files/1115/datos_abiertos_2017_04-1.csv',
#  '/site/assets/files/1116/datos_abiertos_2017_05.csv',
#  '/site/assets/files/1119/datos_abiertos_2017_06.csv',
#  '/site/assets/files/1120/datos_abiertos_2017_07.csv',
#  '/site/assets/files/1122/datos_abiertos_2017_08.csv',
#  '/site/assets/files/1123/datos_abiertos_2017_09.csv',
#  '/site/assets/files/1124/datos_abiertos_2017_10.csv',
#  '/site/assets/files/1197/datos_abiertos_2017_11.csv',
#  '/site/assets/files/1198/datos_abiertos_2017_12.csv',
#  '/site/assets/files/1200/datos_abiertos_2018_01.csv',
#  '/site/assets/files/1201/datos_abiertos_2018_02.csv',
#  '/site/assets/files/1202/datos_abiertos_2018_03.csv',
#  '/site/assets/files/1203/datos_abiertos_2018_04.csv',
#  '/site/assets/files/1204/datos_abiertos_2018_05.csv',
#  '/site/assets/files/1205/datos_abiertos_2018_06.csv',
#  '/site/assets/files/1206/datos_abiertos_2018_07.csv',
#  '/site/assets/files/1207/datos_abiertos_2018_08.csv',
#  '/site/assets/files/1208/datos_abiertos_2018_09.csv',
#  '/site/assets/files/1209/datos_abiertos_2018_10.csv',
#  '/site/assets/files/1210/datos_abiertos_2018_11.csv',
#  '/site/assets/files/1211/datos_abiertos_2018_12.csv',
#  '/site/assets/files/1214/datos_abiertos_2019_01.csv',
#  '/site/assets/files/1217/datos_abiertos_2019_02.csv',
#  '/site/assets/files/1218/datos_abiertos_2019_03.csv',
#  '/site/assets/files/1219/datos_abiertos_2019_04.csv',
#  '/site/assets/files/1220/datos_abiertos_2019_05.csv',
#  '/site/assets/files/1221/datos_abiertos_2019_06.csv',
#  '/site/assets/files/1222/datos_abiertos_2019_07.csv',
#  '/site/assets/files/1223/datos_abiertos_2019_08.csv',
#  '/site/assets/files/1224/datos_abiertos_2019_09.csv',
#  '/site/assets/files/1225/datos_abiertos_2019_10.csv',
#  '/site/assets/files/1227/datos_abiertos_2019_11.csv',
#  '/site/assets/files/1228/datos_abiertos_2019_12.csv',
#  '/site/assets/files/1230/datos_abiertos_2020_01.csv',
#  '/site/assets/files/1231/datos_abiertos_2020_02.csv',
#  '/site/assets/files/1232/datos_abiertos_2020_03.csv',
#  '/site/assets/files/1235/datos_abiertos_2020_04.csv',
#  '/site/assets/files/1236/datos_abiertos_2020_05.csv',
#  '/site/assets/files/1237/datos_abiertos_2020_06.csv',
#  '/site/assets/files/1238/datos_abiertos_2020_07.csv',
#  '/site/assets/files/1239/datos_abiertos_2020_08.csv',
#  '/site/assets/files/1240/datos_abiertos_2020_09.csv',
#  '/site/assets/files/1241/datos_abiertos_2020_10.csv',
#  '/site/assets/files/1317/datos_abiertos_2020_11.csv',
#  '/site/assets/files/1318/datos_abiertos_2020_12.csv',
#  '/site/assets/files/1320/datos_abiertos_2021_01.csv',
#  '/site/assets/files/1323/datos_abiertos_2021_02.csv',
#  '/site/assets/files/1322/datos_abiertos_2021_03.csv',
#  '/site/assets/files/2129/datos_abiertos_2021_04.csv',
#  '/site/assets/files/3292/datos_abiertos_2021_05.csv',
#  '/site/assets/files/4572/datos_abiertos_2021_06.csv',
#  '/site/assets/files/5728/datos_abiertos_2021_07.csv',
#  '/site/assets/files/7073/datos_abiertos_2021_08.csv',
#  '/site/assets/files/8461/datos_abiertos_2021_09.csv',
#  '/site/assets/files/10088/datos_abiertos_2021_10.csv',
#  '/site/assets/files/11538/datos_abiertos_2021_11.csv',
#  '/site/assets/files/12780/datos_abiertos_2021_12.csv',
#  '/site/assets/files/14797/datos_abiertos_2022_01.csv',
#  '/site/assets/files/16831/datos_abiertos_2022_02.csv',
#  '/site/assets/files/19034/datos_abiertos_2022_03.csv',
#  '/site/assets/files/20338/datos_abiertos_2022_04.csv',
#  '/site/assets/files/21842/datos_abiertos_2022_05.csv',
#  '/site/assets/files/23473/datos_abiertos_2022_06.csv',
#  '/site/assets/files/25235/datos_abiertos_2022_07.csv',
#  '/site/assets/files/27484/datos_abiertos_2022_08.csv',
#  '/site/assets/files/29663/datos_abiertos_2022_09.csv',
#  '/site/assets/files/31507/datos_abiertos_2022_10.csv',
#  '/site/assets/files/33115/datos_abiertos_2022_11.csv',
#  '/site/assets/files/1118/nomenclatura_2022_11.csv']

# %% [markdown]
# Retreive all of the csv files from the website by iterating through each list item and leveraging the `webbrowser` library to open each respective download link.

# %%
url2 = 'https://www.mibici.net'
for file in data_files:
    webbrowser.open_new(url2 + file)
    sleep(60)

# %% [markdown]
# After downloading all of the respective files, relocate them from the `/Download` folder to the destination folder of the project.

# %%
source = 'C:/Users/Delan/Downloads/'
destination = '../../MiBici_Data/Original_BikeData/'

# Unzip files and clean up data folder
keywords = ['datos_abiertos', 'nomenclatura_2022']

# Move from Download folder to data folder
for item in os.listdir(source):
    for keyword in keywords:
        if keyword in item:
            shutil.move(source + item, destination)

# %% [markdown]
# Move the nomenclature file (with station data) to the parent folder.

# %%
source = '../../MiBici_Data/Original_BikeData/'
destination = '../../MiBici_Data/'

# Unzip files and clean up data folder
keywords = ['nomenclatura_2022']

# Move from Download folder to data folder
for item in os.listdir(source):
    for keyword in keywords:
        if keyword in item:
            shutil.move(source + item, destination)

# %% [markdown]
# ## Fix Column Names

# %% [markdown]
# Check the details of the files, see what column headers they all share in common.
# * They share all have the same columns except the birth year of the rider.
# * There is an issue with the `ñ` in the word `año` for the birth year variable between some files.

# %%
files = glob.glob(r'../../MiBici_Data/Original_BikeData/*.csv')

# %%
def get_common_columns(files, **kwargs):
    
    #Get set intersection of column-names of specified CSV files
    common_columns = set(pd.read_csv(files[0], nrows=0, **kwargs, encoding='latin-1').columns)
    
    for f in files[1:]:
        common_columns &= set(pd.read_csv(f, nrows=0, **kwargs, encoding='latin-1').columns)
    return common_columns

# %%
get_common_columns(files)
# Out:
# {'Destino_Id',
#  'Fin_del_viaje',
#  'Genero',
#  'Inicio_del_viaje',
#  'Origen_Id',
#  'Usuario_Id',
#  'Viaje_Id'}

# %% [markdown]
# Change column names and add additional variables to each file

# %%
# function to translate the columns names into English
def fix_colNames(data_frame):
    return data_frame.rename(columns=({'Viaje_Id'          :'Trip_ID',
                                       'Usuario_Id'        :'User_ID',
                                       'Genero'            :'Gender',
                                       'Año_de_nacimiento' :'Birth_Year',
                                       'AÃ±o_de_nacimiento':'Birth_Year',
                                 
                                       'Inicio_del_viaje' :'Start_Time',
                                       'Fin_del_viaje'    :'End_Time',
                                       'Origen_Id'        :'Start_Station_ID',
                                       'Destino_Id'       :'End_Station_ID'}
                             ))

# %%
# Function to convert start/end time variables into datetime objects and calculate the trip duration
def Create_DateTime(data_frame, index):
    
    data_frame['Start_Time'] = pd.to_datetime(data_frame['Start_Time'])
    data_frame['End_Time'] = pd.to_datetime(data_frame['End_Time'])
    data_frame['Duration'] = (data_frame['End_Time'] - data_frame['Start_Time']).dt.total_seconds()/60

    return data_frame

# %%
# Create more start time variables: hour of days, weekday, and month of trip
# 1 = Monday -> 7 = Sunday
def Create_StartVariables(data_frame):
    
    data_frame['Start_Hour']    = data_frame['Start_Time'].apply(lambda x: x.hour).astype('category')
    data_frame['Start_Month']   = data_frame['Start_Time'].apply(lambda x: x.month).astype('category')
    data_frame['Start_Weekday'] = data_frame['Start_Time'].apply(lambda x: x.isoweekday()).astype('category')
    data_frame['Start_Weekday'] = data_frame['Start_Weekday'].map({1:'Monday', 2:'Tuesday', 3:'Wednesday', 4:'Thursday',
                                                                   5:'Friday', 6:'Saturday', 7:'Sunday'})

    return data_frame

# %%
# obtain the csv data file names
oldPath = "../../MiBici_Data/Original_BikeData/"
newPath = "../../MiBici_Data/FirstCleaning/"
file_index = 1 # keep track of file count
temp_file_names = [os.path.basename(x) for x in glob.glob(oldPath+'*.csv')]

# Loop through each file, make changes, save in 'CleanData' folder
for file in temp_file_names:
    
    df = pd.read_csv(os.path.join(oldPath, file), encoding='latin-1')     # read in file as dataframe
    
    df = fix_colNames(df)                  # translate/rename columns
    df = Create_DateTime(df, file_index)   # Clean Start/End time variables. Create trip duration variable
    df = Create_StartVariables(df)         # obtain additional info on start_time: hour, weekday, month
    
    # Make a copy of the new formatted file into the 'CleanDataFolder'
    df.to_csv(newPath + file)
    
    file_index = file_index + 1

# %% [markdown]
# ## Add Location Data

# %% [markdown]
# Reverse geolocating is used to obtain more detailed information about the locations of each bike station (e.g., town, neighborhood, etc.).

# %% [markdown]
# Read in the `all_stations_file` that contains the name, latitiude, and longitude information for each bike station

# %%
all_stations_df = pd.read_csv('../../MiBici_Data/nomenclatura_2022_11.csv', encoding='latin-1')

# %% [markdown]
# Take a peek at the dataframe.

# %%
all_stations_df.head()
# Out:
#    id                                           name     obcn  \
# 0   2  (GDL-001) C. Epigmenio Glez./ Av. 16 de Sept.  GDL-001
# 1   3     (GDL-002) C. Colonias  / Av.  Niños héroes  GDL-002
# 2   4          (GDL-003) C. Vidrio / Av. Chapultepec  GDL-003
# 3   5           (GDL-004) C. Ghilardi /C. Miraflores  GDL-004
# 4   6  (GDL-005) C. San Diego /Calzada Independencia  GDL-005
#
#            location   latitude   longitude      status
# 0  POLÍGONO CENTRAL  20.666378 -103.348820  IN_SERVICE
# 1  POLÍGONO CENTRAL  20.667228 -103.366000  IN_SERVICE
# 2  POLÍGONO CENTRAL  20.667690 -103.368252  IN_SERVICE
# 3  POLÍGONO CENTRAL  20.691750 -103.362550  IN_SERVICE
# 4  POLÍGONO CENTRAL  20.681151 -103.338863  IN_SERVICE

# %% [markdown]
# Check for missing data.

# %%
all_stations_df.isnull().values.any()
# Out:
# False

# %% [markdown]
# Create a new variable that concatenates the latitude and longitude.

# %%
all_stations_df['geometry'] = all_stations_df['latitude'].map(str) + ',' + all_stations_df['longitude'].map(str)

# %%
all_stations_df.head(10)
# Out:
#    id                                           name     obcn  \
# 0   2  (GDL-001) C. Epigmenio Glez./ Av. 16 de Sept.  GDL-001
# 1   3     (GDL-002) C. Colonias  / Av.  Niños héroes  GDL-002
# 2   4          (GDL-003) C. Vidrio / Av. Chapultepec  GDL-003
# 3   5           (GDL-004) C. Ghilardi /C. Miraflores  GDL-004
# 4   6  (GDL-005) C. San Diego /Calzada Independencia  GDL-005
# 5   8   (GDL-006) C. Venustiano Carranza /C. Reforma  GDL-006
# 6   9  (GDL-007) C. Epigmenio Glez./Av. Cristobal C.  GDL-007
# 7  10    (GDL-008) C. J. Angulo / C. González Ortega  GDL-008
# 8  11      (GDL-009) Calz. Federalismo/ C. J. Angulo  GDL-009
# 9  12    (GDL-010) C. Cruz verde / C. Joaquin Angulo  GDL-010
#
#            location   latitude   longitude      status  \
# 0  POLÍGONO CENTRAL  20.666378 -103.348820  IN_SERVICE
# 1  POLÍGONO CENTRAL  20.667228 -103.366000  IN_SERVICE
# 2  POLÍGONO CENTRAL  20.667690 -103.368252  IN_SERVICE
# 3  POLÍGONO CENTRAL  20.691750 -103.362550  IN_SERVICE
# 4  POLÍGONO CENTRAL  20.681151 -103.338863  IN_SERVICE
# 5  POLÍGONO CENTRAL  20.680717 -103.344415  IN_SERVICE
# 6  POLÍGONO CENTRAL  20.666771 -103.350562  IN_SERVICE
# 7  POLÍGONO CENTRAL  20.681871 -103.350396  IN_SERVICE
# 8  POLÍGONO CENTRAL  20.681984 -103.353835  IN_SERVICE
# 9  POLÍGONO CENTRAL  20.681852 -103.357338  IN_SERVICE
#
#                   geometry
# 0     20.666378,-103.34882
# 1       20.667228,-103.366
# 2     20.66769,-103.368252
# 3      20.69175,-103.36255
# 4    20.681151,-103.338863
# 5    20.680717,-103.344415
# 6    20.666771,-103.350562
# 7    20.681871,-103.350396
# 8    20.681984,-103.353835
# 9  20.6818519,-103.3573381

# %% [markdown]
# Reverse geolocate each station

# %%
import geopy
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter

# %%
from geopy.geocoders import Photon
locator = Photon(user_agent="measurements")

#locator = Nominatim(user_agent='myGeocoder', timeout=10)
rgeocode = RateLimiter(locator.reverse, min_delay_seconds=0.001)

# %%
all_stations_df['address'] = all_stations_df['geometry'].apply(rgeocode)

# %%
all_stations_df.head()
# Out:
#    id                                           name     obcn  \
# 0   2  (GDL-001) C. Epigmenio Glez./ Av. 16 de Sept.  GDL-001
# 1   3     (GDL-002) C. Colonias  / Av.  Niños héroes  GDL-002
# 2   4          (GDL-003) C. Vidrio / Av. Chapultepec  GDL-003
# 3   5           (GDL-004) C. Ghilardi /C. Miraflores  GDL-004
# 4   6  (GDL-005) C. San Diego /Calzada Independencia  GDL-005
#
#            location   latitude   longitude      status               geometry  \
# 0  POLÍGONO CENTRAL  20.666378 -103.348820  IN_SERVICE   20.666378,-103.34882
# 1  POLÍGONO CENTRAL  20.667228 -103.366000  IN_SERVICE     20.667228,-103.366
# 2  POLÍGONO CENTRAL  20.667690 -103.368252  IN_SERVICE   20.66769,-103.368252
# 3  POLÍGONO CENTRAL  20.691750 -103.362550  IN_SERVICE    20.69175,-103.36255
# 4  POLÍGONO CENTRAL  20.681151 -103.338863  IN_SERVICE  20.681151,-103.338863
#
#                                              address
# 0  (MiBici, Calle Epigmenio González, 44180, Call...
# 1  (MiBici, Calle Colonias, 44140, Calle Colonias...
# 2  (Ui Internacional, 1984, Calle Vidrio, 44150, ...
# 3  (918, Calle Ghilardi, 44610, Calle Ghilardi, G...
# 4  (Calle Esteban Alatorre, 44360, Guadalajara, J...

# %% [markdown]
# Check for missing address data.

# %%
all_stations_df.address.isnull().values.any()
# Out:
# False

# %% [markdown]
# Take a peek at the new address variable

# %%
all_stations_df.address[10].raw
# Out:
# {'geometry': {'coordinates': [-103.360048, 20.6810774], 'type': 'Point'},
#  'type': 'Feature',
#  'properties': {'osm_id': 4316576338,
#   'country': 'México',
#   'city': 'Guadalajara',
#   'countrycode': 'MX',
#   'postcode': '44200',
#   'locality': 'Santa Tere',
#   'type': 'house',
#   'osm_type': 'N',
#   'osm_key': 'amenity',
#   'street': 'Calle Garibaldi',
#   'osm_value': 'bicycle_rental',
#   'name': 'MiBici',
#   'state': 'Jalisco'}}

# %% [markdown]
# Extract the neighbourhood and city names for each bike station.

# %%
# neighborhood
all_stations_df.address[0].raw.get('properties').get('locality')
# Out:
# 'Mexicaltzingo'

# %%
# city
all_stations_df['address'][0].raw.get('properties').get('city')
# Out:
# 'Guadalajara'

# %%
all_stations_df['city']          = all_stations_df['address'].apply(lambda x : x.raw.get('properties').get('city'))
all_stations_df['neighbourhood'] = all_stations_df['address'].apply(lambda x : x.raw.get('properties').get('locality'))

# %%
all_stations_df.head(5)
# Out:
#    id                                           name     obcn  \
# 0   2  (GDL-001) C. Epigmenio Glez./ Av. 16 de Sept.  GDL-001
# 1   3     (GDL-002) C. Colonias  / Av.  Niños héroes  GDL-002
# 2   4          (GDL-003) C. Vidrio / Av. Chapultepec  GDL-003
# 3   5           (GDL-004) C. Ghilardi /C. Miraflores  GDL-004
# 4   6  (GDL-005) C. San Diego /Calzada Independencia  GDL-005
#
#            location   latitude   longitude      status               geometry  \
# 0  POLÍGONO CENTRAL  20.666378 -103.348820  IN_SERVICE   20.666378,-103.34882
# 1  POLÍGONO CENTRAL  20.667228 -103.366000  IN_SERVICE     20.667228,-103.366
# 2  POLÍGONO CENTRAL  20.667690 -103.368252  IN_SERVICE   20.66769,-103.368252
# 3  POLÍGONO CENTRAL  20.691750 -103.362550  IN_SERVICE    20.69175,-103.36255
# 4  POLÍGONO CENTRAL  20.681151 -103.338863  IN_SERVICE  20.681151,-103.338863
#
#                                              address         city  \
# 0  (MiBici, Calle Epigmenio González, 44180, Call...  Guadalajara
# 1  (MiBici, Calle Colonias, 44140, Calle Colonias...  Guadalajara
# 2  (Ui Internacional, 1984, Calle Vidrio, 44150, ...  Guadalajara
# 3  (918, Calle Ghilardi, 44610, Calle Ghilardi, G...  Guadalajara
# 4  (Calle Esteban Alatorre, 44360, Guadalajara, J...  Guadalajara
#
#        neighbourhood
# 0      Mexicaltzingo
# 1          Americana
# 2             Obrera
# 3  Mezquitán Country
# 4           La Perla

# %% [markdown]
# Check unique values for city & neighborhoods

# %%
set(all_stations_df.city)
# Out:
# {'Guadalajara', 'Guadalajara, Jalisco', None, 'Tlaquepaque', 'Zapopan'}

# %%
set(all_stations_df.neighbourhood)
# Out:
# {'Americana',
#  'Analco',
#  'Arcos Vallarta',
#  'Barranquitas',
#  'Barrio de Mezquitán',
#  'Belenes Norte',
#  'Camino Real',
#  'Capilla de Jesús',
#  'Centro Barranquitas',
#  'Chapalita',
#  'Chapalita Oriente',
#  'Chapultepec Country',
#  'Circunvalación',
#  'Circunvalación Guevara',
#  'Ciudad de los Niños',
#  'Ciudad del Sol',
#  'Colinas de la Normal',
#  'Colonia del Periodista',
#  'Country Plaza',
#  'Don Bosco Vallarta',
#  'El Capullo',
#  'El Vigía',
#  'Guadalajara Centro',
#  'Guadalupe',
#  'Hacendarios',
#  'Ibarra y Molodom',
#  'Independencia Oriente',
#  'Independencia Sur',
#  'Industrial Los Belenes',
#  'Italia',
#  'Jacarandas',
#  'Jardines de Los Arcos 1a Sección',
#  'Jardines de San Ignacio',
#  'Jardines del Bosque',
#  'Jardines del Bosque Norte',
#  'Jardines del Country',
#  'Juan Diego',
#  'La Normal',
#  'La Perla',
#  'Ladrón de Guevara',
#  'Las Flores',
#  'Las Nueve Esquinas',
#  'Laureles',
#  'Loma Blanca',
#  'Los Maestros',
#  'Mexicaltzingo',
#  'Mezquitán',
#  'Mezquitán Country',
#  'Miraflores',
#  'Moderna',
#  None,
#  'Obrera',
#  'Observatorio',
#  'Reforma',
#  'República',
#  'Revolucion',
#  'Rinconada de la Azalea',
#  'Rinconada de la Victoria',
#  'Rinconada del Sol',
#  'Rinconada del Valle',
#  'Rojas Ladrón de Guevara',
#  'San Isidro Ejidal',
#  'San José del Bajío',
#  'San Juan de Dios',
#  'San Miguel de Mezquitán',
#  'San Patricio',
#  'Santa Tere',
#  'Tepeyac',
#  'Tepeyac Casino',
#  'Unidad Modelo',
#  'Vallarta Cuauhtémoc',
#  'Vallarta Sur',
#  'Verde Valle 3a Sección',
#  'Villa Magna',
#  'Villas Belenes',
#  'Villaseñor',
#  'Zapopan Centro'}

# %% [markdown]
# Truncate city name from `Guadalajara, Jalisco` to `Guadalajara`

# %%
# Only one item is listed as 'Guadalajara, Jalisco'
sum(all_stations_df['city'] == 'Guadalajara, Jalisco')
# Out:
# 1

# %%
all_stations_df.loc[all_stations_df['city'] == 'Guadalajara, Jalisco', 'city'] = 'Guadalajara'

# %% [markdown]
# Check for missing data:
# * Rows with missing neighborhood data are manually corrected.

# %%
all_stations_df.isnull().values.any()
# Out:
# True

# %%
all_stations_df.isnull().sum()
# Out:
# id                0
# name              0
# obcn              0
# location          0
# latitude          0
# longitude         0
# status            0
# geometry          0
# address           0
# city              1
# neighbourhood    29
# dtype: int64

# %% [markdown]
# Remove text in parenthesis in name column

# %%
all_stations_df.head(5)
# Out:
#    id                                           name     obcn  \
# 0   2  (GDL-001) C. Epigmenio Glez./ Av. 16 de Sept.  GDL-001
# 1   3     (GDL-002) C. Colonias  / Av.  Niños héroes  GDL-002
# 2   4          (GDL-003) C. Vidrio / Av. Chapultepec  GDL-003
# 3   5           (GDL-004) C. Ghilardi /C. Miraflores  GDL-004
# 4   6  (GDL-005) C. San Diego /Calzada Independencia  GDL-005
#
#            location   latitude   longitude      status               geometry  \
# 0  POLÍGONO CENTRAL  20.666378 -103.348820  IN_SERVICE   20.666378,-103.34882
# 1  POLÍGONO CENTRAL  20.667228 -103.366000  IN_SERVICE     20.667228,-103.366
# 2  POLÍGONO CENTRAL  20.667690 -103.368252  IN_SERVICE   20.66769,-103.368252
# 3  POLÍGONO CENTRAL  20.691750 -103.362550  IN_SERVICE    20.69175,-103.36255
# 4  POLÍGONO CENTRAL  20.681151 -103.338863  IN_SERVICE  20.681151,-103.338863
#
#                                              address         city  \
# 0  (MiBici, Calle Epigmenio González, 44180, Call...  Guadalajara
# 1  (MiBici, Calle Colonias, 44140, Calle Colonias...  Guadalajara
# 2  (Ui Internacional, 1984, Calle Vidrio, 44150, ...  Guadalajara
# 3  (918, Calle Ghilardi, 44610, Calle Ghilardi, G...  Guadalajara
# 4  (Calle Esteban Alatorre, 44360, Guadalajara, J...  Guadalajara
#
#        neighbourhood
# 0      Mexicaltzingo
# 1          Americana
# 2             Obrera
# 3  Mezquitán Country
# 4           La Perla

# %%
all_stations_df['name'] = all_stations_df['name'].str.split(')').str[1]

# %%
all_stations_df
# Out:
#       id                                  name     obcn           location  \
# 0      2   C. Epigmenio Glez./ Av. 16 de Sept.  GDL-001   POLÍGONO CENTRAL
# 1      3      C. Colonias  / Av.  Niños héroes  GDL-002   POLÍGONO CENTRAL
# 2      4           C. Vidrio / Av. Chapultepec  GDL-003   POLÍGONO CENTRAL
# 3      5            C. Ghilardi /C. Miraflores  GDL-004   POLÍGONO CENTRAL
# 4      6   C. San Diego /Calzada Independencia  GDL-005   POLÍGONO CENTRAL
# ..   ...                                   ...      ...                ...
# 307  323    C. Palavicini / Av. Circunvalación  GDL-213   POLÍGONO CENTRAL
# 308  324     De los científicos/ J. J. Tablada  GDL-221   POLÍGONO CENTRAL
# 309  325     C. Luis G. Cuevas /Av. Revolución  GDL-226  TLQ-CORREDORATLAS
# 310  326           C. D. Rivera / C. Filósofos  GDL-219   POLÍGONO CENTRAL
# 311  327       C. Artistas / C. Carlos Pereira  GDL-227   POLÍGONO CENTRAL
#
#       latitude   longitude      status               geometry  \
# 0    20.666378 -103.348820  IN_SERVICE   20.666378,-103.34882
# 1    20.667228 -103.366000  IN_SERVICE     20.667228,-103.366
# 2    20.667690 -103.368252  IN_SERVICE   20.66769,-103.368252
# 3    20.691750 -103.362550  IN_SERVICE    20.69175,-103.36255
# 4    20.681151 -103.338863  IN_SERVICE  20.681151,-103.338863
# ..         ...         ...         ...                    ...
# 307  20.704670 -103.345589  IN_SERVICE   20.70467,-103.345589
# 308  20.700192 -103.345961  IN_SERVICE  20.700192,-103.345961
# 309  20.652408 -103.312902  IN_SERVICE  20.652408,-103.312902
# 310  20.698197 -103.342554  IN_SERVICE  20.698197,-103.342554
# 311  20.695636 -103.339378  IN_SERVICE  20.695636,-103.339378
#
#                                                address         city  \
# 0    (MiBici, Calle Epigmenio González, 44180, Call...  Guadalajara
# 1    (MiBici, Calle Colonias, 44140, Calle Colonias...  Guadalajara
# 2    (Ui Internacional, 1984, Calle Vidrio, 44150, ...  Guadalajara
# 3    (918, Calle Ghilardi, 44610, Calle Ghilardi, G...  Guadalajara
# 4    (Calle Esteban Alatorre, 44360, Guadalajara, J...  Guadalajara
# ..                                                 ...          ...
# 307  (Calle Félix Palavicini, 44220, Guadalajara, J...  Guadalajara
# 308  (823, Avenida de los Científicos, 44266, Aveni...  Guadalajara
# 309  (2126, Avenida Revolución, 44410, Avenida Revo...  Guadalajara
# 310  (Calle Paseo de los Filósofos, Calle Paseo de ...  Guadalajara
# 311  (402, Calle Carlos Pereira, 44290, Calle Carlo...  Guadalajara
#
#             neighbourhood
# 0           Mexicaltzingo
# 1               Americana
# 2                  Obrera
# 3       Mezquitán Country
# 4                La Perla
# ..                    ...
# 307      Ibarra y Molodom
# 308            Miraflores
# 309                  None
# 310  Colinas de la Normal
# 311          Barranquitas
#
# [312 rows x 11 columns]

# %% [markdown]
# Save the modified data frame to the project folder

# %%
# all_stations_df.to_csv('../../MiBici_Data/nomenclatura_2022_11_updated.csv', index=False, encoding = 'utf-8')

# %% [markdown]
# ## Combine Station/Main Datasets

# %% [markdown]
# Read in new bike station dataset

# %%
# Location station dataset
all_stations_new_df = pd.read_csv('../../MiBici_Data/nomenclatura_2022_11_updated.csv', encoding='utf-8')

# %%
# Check to make sure formatting is OK
all_stations_new_df.tail(5)
# Out:
#       id                                 name     obcn           location  \
# 307  323   C. Palavicini / Av. Circunvalación  GDL-213   POLÍGONO CENTRAL
# 308  324    De los científicos/ J. J. Tablada  GDL-221   POLÍGONO CENTRAL
# 309  325    C. Luis G. Cuevas /Av. Revolución  GDL-226  TLQ-CORREDORATLAS
# 310  326          C. D. Rivera / C. Filósofos  GDL-219   POLÍGONO CENTRAL
# 311  327      C. Artistas / C. Carlos Pereira  GDL-227   POLÍGONO CENTRAL
#
#       latitude   longitude      status               geometry  \
# 307  20.704670 -103.345589  IN_SERVICE   20.70467,-103.345589
# 308  20.700192 -103.345961  IN_SERVICE  20.700192,-103.345961
# 309  20.652408 -103.312902  IN_SERVICE  20.652408,-103.312902
# 310  20.698197 -103.342554  IN_SERVICE  20.698197,-103.342554
# 311  20.695636 -103.339378  IN_SERVICE  20.695636,-103.339378
#
#                                                address         city  \
# 307  Calle Félix Palavicini, 44220, Guadalajara, Ja...  Guadalajara
# 308  823, Avenida de los Científicos, 44266, Avenid...  Guadalajara
# 309  2126, Avenida Revolución, 44410, Avenida Revol...  Guadalajara
# 310  Calle Paseo de los Filósofos, Calle Paseo de l...  Guadalajara
# 311  402, Calle Carlos Pereira, 44290, Calle Carlos...  Guadalajara
#
#             neighbourhood
# 307      Ibarra y Molodom
# 308            Miraflores
# 309                 Sutaj
# 310  Colinas de la Normal
# 311          Barranquitas

# %% [markdown]
# Loop through each station type (start/end) and merge location data to full dataset

# %%
def CombineLocation(full_df, location_df):
    
    # Set indices of both dataframes for start Locations
    full_df.set_index('Start_Station_ID', drop=False, inplace=True) # Set full dataset index to start index
    location_df.set_index('id', drop=False, inplace=True)           # Set location dataset index to 'id' index

    # Merge location to full dataset
    full_df = pd.merge(full_df, location_df.drop(['id', 'obcn', 'location'], axis=1), left_index=True, right_index=True, how='left')

    # Rename new columns for start locations 
    full_df.rename(columns=({'name'          : 'Start_Name',
                             'latitude'      : 'Start_Latitude',  
                             'longitude'     : 'Start_Longitude',
                             'status'        : 'Start_Status',
                             'geometry'      : 'Start_Geometry',
                             'address'       : 'Start_Address',
                             'city'          : 'Start_City',
                             'neighbourhood' : 'Start_Neighborhood'}
                            ), inplace=True)
    
    # Set indices of both dataframes for start Locations
    full_df.set_index('End_Station_ID', drop=False, inplace=True) # Set full dataset index to start index

    # Merge location to full dataset
    full_df = pd.merge(full_df, location_df.drop(['id', 'obcn', 'location'], axis=1), left_index=True, right_index=True, how='left')

    # Rename new columns for start locations 
    full_df.rename(columns=({'name'          : 'End_Name',
                             'latitude'      : 'End_Latitude',  
                             'longitude'     : 'End_Longitude',
                             'status'        : 'End_Status',
                             'geometry'      : 'End_Geometry',
                             'address'       : 'End_Address',
                             'city'          : 'End_City',
                             'neighbourhood' : 'End_Neighborhood'}
                            ), inplace=True)
    return full_df

# %%
# obtain the csv data file names
oldPath = "../../MiBici_Data/FirstCleaning/"
newPath = "../../MiBici_Data/SecondCleaning/"
files = [os.path.basename(x) for x in glob.glob('../../MiBici_Data/FirstCleaning/*.csv')]

# Loop through each file, make changes, save in 'SecondCleaning' folder
for file in files:
    
    df = pd.read_csv(os.path.join(oldPath, file), encoding='utf-8')           # read in file as dataframe
    df = CombineLocation(df, all_stations_new_df)                               # add bike station data
    df.iloc[:, 1:].to_csv(newPath + file, index=False, encoding = 'utf-8')    # Make a copy of the new formatted file into the 'SecondCleaning' without extrax index column

# %% [markdown]
# # Missing Data

# %% [markdown]
# Upload data and separate into data frames by year

# %%
# obtain the csv data file names
path = "../../MiBici_Data/SecondCleaning/"
files = [file for file in os.listdir(path) if file.endswith(".csv")]

# %%
# Loop through each file, check what year its from, save in appropriate dataframe
MiBici2017 = pd.DataFrame()
MiBici2018 = pd.DataFrame()
MiBici2019 = pd.DataFrame()
MiBici2020 = pd.DataFrame()
MiBici2021 = pd.DataFrame()
MiBici2022 = pd.DataFrame()

for file in files:
    if file[15:19] == '2017':
        df_temp = pd.read_csv(os.path.join(path, file), encoding='utf-8')
        MiBici2017 = pd.concat([MiBici2017, df_temp], axis=0)
        
    elif file[15:19] == '2018':
        df_temp = pd.read_csv(os.path.join(path, file), encoding='utf-8')
        MiBici2018 = pd.concat([MiBici2018, df_temp], axis=0)
        
    elif file[15:19] == '2019':
        df_temp = pd.read_csv(os.path.join(path, file), encoding='utf-8')
        MiBici2019 = pd.concat([MiBici2019, df_temp], axis=0)
        
    elif file[15:19] == '2020':
        df_temp = pd.read_csv(os.path.join(path, file), encoding='utf-8')
        MiBici2020 = pd.concat([MiBici2020, df_temp], axis=0)
        
    elif file[15:19] == '2021':
        df_temp = pd.read_csv(os.path.join(path, file), encoding='utf-8')
        MiBici2021 = pd.concat([MiBici2021, df_temp], axis=0)
    
    elif file[15:19] == '2022':
        df_temp = pd.read_csv(os.path.join(path, file), encoding='utf-8')
        MiBici2022 = pd.concat([MiBici2022, df_temp], axis=0)

# %% [markdown]
# Check for missing data
# * Rides with missing Gender & Birth Year data will not be deleted
# * Rows with missing location-related data, are not missing all the same data

# %%
pd.concat([MiBici2017.isna().sum(),
           MiBici2018.isna().sum(),
           MiBici2019.isna().sum(),
           MiBici2020.isna().sum(),
           MiBici2021.isna().sum(),
           MiBici2022.isna().sum()], axis=1)
# Out:
#                         0      1      2     3     4      5
# Trip_ID                 0      0      0     0     0      0
# User_ID                 0      0      0     0     0      0
# Gender                  0      0   6415  3349  4832  14888
# Birth_Year          12752  11621  11522  3447  4332  13092
# Start_Time              0      0      0     0     0      0
# End_Time                0      0      0     0     0      0
# Start_Station_ID        0      0      0     0     0      0
# End_Station_ID          0      0      0     0     0      0
# Duration                0      0      0     0     0      0
# Start_Hour              0      0      0     0     0      0
# Start_Month             0      0      0     0     0      0
# Start_Weekday           0      0      0     0     0      0
# Start_Name          26175  18265   6208  1105     0      0
# Start_Latitude         18      0     16     6     0      0
# Start_Longitude        18      0     16     6     0      0
# Start_Status           18      0     16     6     0      0
# Start_Geometry         18      0     16     6     0      0
# Start_Address          18      0     16     6     0      0
# Start_City             18      0     16     6     0      0
# Start_Neighborhood     18      0     16     6     0      0
# End_Name            25587  18309   5314  1007     0      0
# End_Latitude           17      2     19     4     0      0
# End_Longitude          17      2     19     4     0      0
# End_Status             17      2     19     4     0      0
# End_Geometry           17      2     19     4     0      0
# End_Address            17      2     19     4     0      0
# End_City               17      2     19     4     0      0
# End_Neighborhood       17      2     19     4     0      0

# %% [markdown]
# Further investigate rides with missing location-related data

# %%
MiBici2019[MiBici2019['End_Latitude'].isna()]
# Out:
#          Trip_ID  User_ID Gender  Birth_Year           Start_Time  \
# 222559   9203980   461651      F      1984.0  2019-01-22 12:59:14
# 222560   9281028   375312      M      2001.0  2019-01-26 14:15:45
# 222561   9283217   244263      F      1994.0  2019-01-26 16:42:19
# 222562   9280457   330512      F      1991.0  2019-01-26 13:47:18
# 222563   9280458   254240      F      1983.0  2019-01-26 13:47:24
# 222564   9280461   226501      M      1993.0  2019-01-26 13:47:31
# 222565   9185846   471777      M      1972.0  2019-01-21 14:05:23
# 222566   9232978   307675      F      1993.0  2019-01-23 19:38:09
# 222567   9232992   307675      F      1993.0  2019-01-23 19:38:33
# 222568   9277390   335131      F      1989.0  2019-01-26 10:18:33
# 222569   9281544   471672      F      1991.0  2019-01-26 14:44:13
# 222570   9281559   471672      F      1991.0  2019-01-26 14:45:10
# 222571   9281614   474227      F      1993.0  2019-01-26 14:48:11
# 222572   9281749   220341      M      1993.0  2019-01-26 14:56:53
# 222573   9319888    16370      M      1996.0  2019-01-29 11:00:29
# 211489   9766785   452513      M      1989.0  2019-02-25 20:52:38
# 231246   9971776   462143      F      1997.0  2019-03-10 08:43:11
# 218489  12366645   550520      F      1994.0  2019-08-14 14:37:47
# 218490  12555677   244500      M      1998.0  2019-08-26 19:32:10
#
#                    End_Time  Start_Station_ID  End_Station_ID   Duration  \
# 222559  2019-01-22 13:09:05                57             124   9.850000
# 222560  2019-01-26 14:30:31                60             124  14.766667
# 222561  2019-01-26 16:46:37                69             124   4.300000
# 222562  2019-01-26 14:06:40                87             124  19.366667
# 222563  2019-01-26 14:07:14                87             124  19.833333
# 222564  2019-01-26 14:05:50                87             124  18.316667
# 222565  2019-01-21 14:05:39               124             124   0.266667
# 222566  2019-01-23 19:38:20               124             124   0.183333
# 222567  2019-01-23 19:38:41               124             124   0.133333
# 222568  2019-01-26 10:19:17               124             124   0.733333
# 222569  2019-01-26 14:44:56               124             124   0.716667
# 222570  2019-01-26 14:45:28               124             124   0.300000
# 222571  2019-01-26 14:48:27               124             124   0.266667
# 222572  2019-01-26 14:57:03               124             124   0.166667
# 222573  2019-01-29 11:44:03               124             124  43.566667
# 211489  2019-02-25 21:11:59                63             124  19.350000
# 231246  2019-03-10 08:52:33                43             124   9.366667
# 218489  2019-08-14 14:55:31               191             124  17.733333
# 218490  2019-08-26 19:39:31               284             124   7.350000
#
#         Start_Hour  ...   Start_City  Start_Neighborhood End_Name  \
# 222559          12  ...  Guadalajara  Las Nueve Esquinas      NaN
# 222560          14  ...  Guadalajara  Las Nueve Esquinas      NaN
# 222561          16  ...  Guadalajara       Mexicaltzingo      NaN
# 222562          13  ...  Guadalajara              Obrera      NaN
# 222563          13  ...  Guadalajara              Obrera      NaN
# 222564          13  ...  Guadalajara              Obrera      NaN
# 222565          14  ...          NaN                 NaN      NaN
# 222566          19  ...          NaN                 NaN      NaN
# 222567          19  ...          NaN                 NaN      NaN
# 222568          10  ...          NaN                 NaN      NaN
# 222569          14  ...          NaN                 NaN      NaN
# 222570          14  ...          NaN                 NaN      NaN
# 222571          14  ...          NaN                 NaN      NaN
# 222572          14  ...          NaN                 NaN      NaN
# 222573          11  ...          NaN                 NaN      NaN
# 211489          20  ...  Guadalajara           Americana      NaN
# 231246           8  ...  Guadalajara          Santa Tere      NaN
# 218489          14  ...  Guadalajara      Arcos Vallarta      NaN
# 218490          19  ...  Guadalajara             Moderna      NaN
#
#         End_Latitude  End_Longitude End_Status End_Geometry End_Address  \
# 222559           NaN            NaN        NaN          NaN         NaN
# 222560           NaN            NaN        NaN          NaN         NaN
# 222561           NaN            NaN        NaN          NaN         NaN
# 222562           NaN            NaN        NaN          NaN         NaN
# 222563           NaN            NaN        NaN          NaN         NaN
# 222564           NaN            NaN        NaN          NaN         NaN
# 222565           NaN            NaN        NaN          NaN         NaN
# 222566           NaN            NaN        NaN          NaN         NaN
# 222567           NaN            NaN        NaN          NaN         NaN
# 222568           NaN            NaN        NaN          NaN         NaN
# 222569           NaN            NaN        NaN          NaN         NaN
# 222570           NaN            NaN        NaN          NaN         NaN
# 222571           NaN            NaN        NaN          NaN         NaN
# 222572           NaN            NaN        NaN          NaN         NaN
# 222573           NaN            NaN        NaN          NaN         NaN
# 211489           NaN            NaN        NaN          NaN         NaN
# 231246           NaN            NaN        NaN          NaN         NaN
# 218489           NaN            NaN        NaN          NaN         NaN
# 218490           NaN            NaN        NaN          NaN         NaN
#
#        End_City End_Neighborhood
# 222559      NaN              NaN
# 222560      NaN              NaN
# 222561      NaN              NaN
# 222562      NaN              NaN
# 222563      NaN              NaN
# 222564      NaN              NaN
# 222565      NaN              NaN
# 222566      NaN              NaN
# 222567      NaN              NaN
# 222568      NaN              NaN
# 222569      NaN              NaN
# 222570      NaN              NaN
# 222571      NaN              NaN
# 222572      NaN              NaN
# 222573      NaN              NaN
# 211489      NaN              NaN
# 231246      NaN              NaN
# 218489      NaN              NaN
# 218490      NaN              NaN
#
# [19 rows x 28 columns]

# %% [markdown]
# # Clean Trip Duration

# %% [markdown]
# Summary Statistics
# * Each year has trip durations over 100 hrs long
# * These are likely not true trips (stolen bike, uncorrectly parked, etc.)

# %%
pd.concat([MiBici2017.Duration.describe().apply(lambda x: '%.2f' % x),
           MiBici2018.Duration.describe().apply(lambda x: '%.2f' % x),
           MiBici2019.Duration.describe().apply(lambda x: '%.2f' % x),
           MiBici2020.Duration.describe().apply(lambda x: '%.2f' % x),
           MiBici2021.Duration.describe().apply(lambda x: '%.2f' % x),
           MiBici2022.Duration.describe().apply(lambda x: '%.2f' % x)
          ], axis=1)
# Out:
#          Duration    Duration    Duration    Duration    Duration    Duration
# count  2516534.00  3403485.00  4636652.00  2866072.00  3184410.00  3499198.00
# mean        38.57       11.45       11.53       11.33       11.02       10.77
# std       1891.91      109.93       98.86       27.37       26.87        8.97
# min          0.00        0.00        0.02        0.00        0.00        0.00
# 25%          5.83        5.82        5.85        5.82        5.70        5.55
# 50%          9.42        9.43        9.55        9.63        9.48        9.30
# 75%         14.63       14.60       14.80       14.87       14.72       14.57
# max     629228.77   125404.75   118583.15    24783.35    28150.77     2754.52

# %% [markdown]
# Check the histograms and percentiles of the trip duration column

# %%
# Loop through each dataset and create its plot
years_df = [MiBici2017, MiBici2018, MiBici2019, MiBici2020, MiBici2021, MiBici2022]
years = ['2017', '2018', '2019', '2020', '2021', '2022']

fig, axs = plt.subplots(ncols=6, figsize=(40, 5), sharey=True)
for i in range(len(years)):
    sns.histplot(years_df[i]['Duration'], bins=range(0, 200, 1),  ax=axs[i])
    axs[i].set_title(years[i])
plt.show()

# %%
# the 99.8% percentile makes the most sense to use (all rides < roughly 2 hrs)
quantiles = [.99, .9975, .998, .9985, .999]

pd.DataFrame([[round(years_df[i].Duration.quantile(quantiles[n]), 4) for i in range(len(years))] \
              for n in range(len(quantiles))],
             columns=years, index = quantiles)
# Out:
#             2017      2018      2019     2020     2021     2022
# 0.9900   34.8167   33.7833   33.8167  33.0333  32.6152  32.3667
# 0.9975   78.1222   54.4333   51.5833  47.5333  43.9833  43.4500
# 0.9980  100.6634   62.5500   58.4000  51.9476  46.4667  45.6500
# 0.9985  147.5734   79.1462   71.9500  59.6316  50.4231  49.2500
# 0.9990  266.6989  111.7919  106.4283  77.7667  57.6167  55.8634

# %% [markdown]
# Remove the trips that have a trip duration larger than the 99% percentile

# %%
MiBici2017 = MiBici2017[MiBici2017.Duration <= MiBici2017.Duration.quantile(.998)]
MiBici2018 = MiBici2018[MiBici2018.Duration <= MiBici2018.Duration.quantile(.998)]
MiBici2019 = MiBici2019[MiBici2019.Duration <= MiBici2019.Duration.quantile(.998)]
MiBici2020 = MiBici2020[MiBici2020.Duration <= MiBici2020.Duration.quantile(.998)]
MiBici2021 = MiBici2021[MiBici2021.Duration <= MiBici2021.Duration.quantile(.998)]
MiBici2022 = MiBici2022[MiBici2022.Duration <= MiBici2022.Duration.quantile(.998)]

# %% [markdown]
# Remove trips with a duration less than 1.5 minutes

# %%
MiBici2017 = MiBici2017[MiBici2017.Duration >= 1.5]
MiBici2018 = MiBici2018[MiBici2018.Duration >= 1.5]
MiBici2019 = MiBici2019[MiBici2019.Duration >= 1.5]
MiBici2020 = MiBici2020[MiBici2020.Duration >= 1.5]
MiBici2021 = MiBici2021[MiBici2021.Duration >= 1.5]
MiBici2022 = MiBici2022[MiBici2022.Duration >= 1.5]

# %% [markdown]
# New Summary Statistics

# %%
pd.concat([MiBici2017.Duration.describe().apply(lambda x: '%.2f' % x),
           MiBici2018.Duration.describe().apply(lambda x: '%.2f' % x),
           MiBici2019.Duration.describe().apply(lambda x: '%.2f' % x),
           MiBici2020.Duration.describe().apply(lambda x: '%.2f' % x),
           MiBici2021.Duration.describe().apply(lambda x: '%.2f' % x),
           MiBici2022.Duration.describe().apply(lambda x: '%.2f' % x)
          ], axis=1)
# Out:
#          Duration    Duration    Duration    Duration    Duration
# count  2445638.00  3299857.00  4480232.00  2758939.00  3053133.00
# mean        11.23       11.18       11.31       11.34       11.23
# std          7.19        6.82        6.85        6.77        6.69
# min          1.50        1.50        1.50        1.50        1.50
# 25%          6.08        6.10        6.17        6.20        6.12
# 50%          9.62        9.65        9.80        9.92        9.80
# 75%         14.78       14.75       14.98       15.07       14.95
# max        100.62       62.55       58.40       51.93       46.47

# %%
# Loop through each dataset and create its plot
fig, axs = plt.subplots(ncols=6, figsize=(40, 5), sharey=True)
for i in range(len(years)):
    sns.histplot(years_df[i]['Duration'], bins=range(0,150,1), ax=axs[i])
    axs[i].set_title(years[i])
plt.show()

# %% [markdown]
# # Summary Statistics

# %% [markdown]
# ## Trip Counts

# %%
tripCount_df = pd.DataFrame([len(MiBici2017),
                             len(MiBici2018),
                             len(MiBici2019),
                             len(MiBici2020),
                             len(MiBici2021),
                             len(MiBici2022)],
                            columns=['Count'],
           index=years)
tripCount_df
# Out:
#         Count
# 2017  2445638
# 2018  3299857
# 2019  4480232
# 2020  2758939
# 2021  3053133
# 2022  3499198

# %%
plt.bar(tripCount_df.index, tripCount_df.Count)
plt.show()

# %%
pd.DataFrame([years_df[i].groupby(["Start_City"]).size().apply(lambda x: '%.0f' % x) \
              for i in range(len(years)) 
             ], index=years)
# Out:
# Start_City Guadalajara Tlaquepaque Zapopan
# 2017           2301672       43898  100062
# 2018           3109198       60444  130215
# 2019           4160350       73177  246697
# 2020           2544840       46981  167115
# 2021           2768083       49003  236047
# 2022           3152455       50657  296086

# %%
pd.DataFrame([years_df[i].groupby(["Start_City"]).size().apply(lambda x: '%.0f' % x) \
              for i in range(len(years)) 
             ], index=years).astype(int).plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Gender

# %%
# Statistics
pd.DataFrame([years_df[i].Gender.astype('category').describe(include='category') \
              for i in range(len(years)) 
             ], index=years)
# Out:
#         count  unique top     freq
# 2017  2516534       2   M  1899924
# 2018  3403485       2   M  2543132
# 2019  4630237       2   M  3439925
# 2020  2862723       2   M  2114951
# 2021  3179578       2   M  2315220
# 2022  3484310       2   M  2536389

# %%
# Loop through each dataset and create its plot
fig, axs = plt.subplots(ncols=6, figsize=(15, 3), sharey=True)
for i in range(len(years)):
    sns.countplot(x = 'Gender', data = years_df[i], ax=axs[i])
    axs[i].set_title(years[i])
plt.show()

# %% [markdown]
# ## Birth Year

# %%
# Statistics
pd.DataFrame([years_df[i].Birth_Year.describe().apply(lambda x: '%.0f' % x) \
              for i in range(len(years)) 
             ], index=years)
# Out:
#         count  mean std   min   25%   50%   75%   max
# 2017  2503782  1985  10  1917  1981  1988  1992  2001
# 2018  3391864  1986  10  1917  1982  1989  1993  2002
# 2019  4625130  1987  10  1917  1982  1990  1994  2003
# 2020  2862625  1987  10  1917  1982  1990  1994  2003
# 2021  3180078  1987  25     1  1982  1990  1995  2021
# 2022  3486106  1988  21     1  1984  1991  1996  2022

# %% [markdown]
# 2021 & 20222 datasets:
# * Replace Birth year < 1917 with NaN (like all other years)
# * Replace Birth year > 2005 & 2006 with NaN (like all other years, youngest rides are 16 yrs old because this is the youngest age an user can get a subscription [MiBici](https://www.mibici.net/es/preguntas-frecuentes/)

# %%
MiBici2021['Birth_Year'] = MiBici2021.Birth_Year.mask(MiBici2021.Birth_Year > 2005)
MiBici2021['Birth_Year'] = MiBici2021.Birth_Year.mask(MiBici2021.Birth_Year < 1917)

MiBici2022['Birth_Year'] = MiBici2022.Birth_Year.mask(MiBici2022.Birth_Year > 2006)
MiBici2022['Birth_Year'] = MiBici2022.Birth_Year.mask(MiBici2022.Birth_Year < 1917)

# %%
# Check stats again
years_df = [MiBici2017, MiBici2018, MiBici2019, MiBici2020, MiBici2021, MiBici2022]

pd.DataFrame([years_df[i].Birth_Year.describe().apply(lambda x: '%.0f' % x) \
              for i in range(len(years)) 
             ], index=years)
# Out:
#         count  mean std   min   25%   50%   75%   max
# 2017  2434038  1985  10  1917  1981  1988  1992  2001
# 2018  3289613  1986  10  1917  1982  1989  1993  2002
# 2019  4470149  1987  10  1917  1982  1990  1994  2003
# 2020  2756023  1987  10  1917  1981  1990  1994  2003
# 2021  3048556  1987  10  1918  1982  1990  1995  2005
# 2022  3485294  1989  10  1920  1984  1991  1996  2006

# %% [markdown]
# ## Age

# %% [markdown]
# Calculate age from birth year

# %%
for i in range(len(years)):
    years_df[i]['Age'] = int(years[i]) - years_df[i].Birth_Year

# %%
# Move age column next to birth year column
for yr in years_df:
    column_to_move = yr.pop("Age")
    yr.insert(4, "Age", column_to_move)

# %% [markdown]
# Age stats:
# * The most common rider age (mode) was 27, 26, 25, 26, 27 years respectively
# * The mean ages are betwwn 32-34 years
# * Median age is between 29-31 years

# %%
# stats as integers
pd.DataFrame([years_df[i].Age.describe().apply(lambda x: '%.0f' % x) \
              for i in range(len(years)) 
             ], index=years)
# Out:
#         count mean std min 25% 50% 75%  max
# 2017  2434038   32  10  16  25  29  36  100
# 2018  3289613   32  10  16  25  29  36  101
# 2019  4470149   32  10  16  25  29  37  102
# 2020  2756023   33  10  17  26  30  39  103
# 2021  3048556   34  10  16  26  31  39  103
# 2022  3485294   33  10  16  26  31  38  102

# %%
# stats as categories
pd.DataFrame([years_df[i].Age.astype('category').describe(include='category').apply(lambda x: '%.0f' % x) \
              for i in range(len(years)) 
             ], index=years)
# Out:
#         count unique top    freq
# 2017  2434038     67  27  167421
# 2018  3289613     70  26  214087
# 2019  4470149     71  25  270962
# 2020  2756023     69  26  157156
# 2021  3048556     70  27  169734
# 2022  3485294     69  26  208326

# %% [markdown]
# Categorize ages into bins

# %%
for i in range(len(years)):
    years_df[i]['Age_category'] = pd.cut(years_df[i]['Age'], 
                                         bins = [0,20,30,40,50,60,70,80,200], 
                                         labels = ["<20", "20s", "30s", "40s", "50s", "60s", "70s", "80+"], 
                                         include_lowest=True)

# %% [markdown]
# Statistics & Plot

# %%
pd.DataFrame([years_df[i].Age_category.describe() \
              for i in range(len(years)) 
             ], index=years)
# Out:
#         count  unique  top     freq
# 2017  2434038       8  20s  1285966
# 2018  3289613       8  20s  1746270
# 2019  4470149       8  20s  2306069
# 2020  2756023       8  20s  1299905
# 2021  3048556       8  20s  1378080
# 2022  3485294       8  20s  1600350

# %%
# Move age column next to borth year column
fig, axs = plt.subplots(ncols=6, figsize=(20, 3), sharey=True)
for i in range(len(years)):
    sns.countplot(x="Age_category", data=years_df[i], ax=axs[i])
    axs[i].set_title(years[i])
plt.show()

# %% [markdown]
# ## Age by Gender

# %%
fig, axs = plt.subplots(ncols=6, figsize=(20, 5), sharey=True)
for i in range(len(years)):
    sns.boxplot(x="Gender", y="Age",  data=years_df[i], ax=axs[i])
    axs[i].set_title(years[i])
plt.show()

# %% [markdown]
# ## Day of the Week

# %% [markdown]
# Most popular day to use the system (Monday-Wednesday)

# %%
# 1 = Monday -> 7 = Sunday
weekday_name = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']

fig, axs = plt.subplots(nrows=6, figsize=(5, 15), sharex=True)
for i in range(len(years)):
    sns.countplot(x="Start_Weekday", data=years_df[i], ax=axs[i])
    axs[i].set_title(years[i])

plt.show()

# %% [markdown]
# Most popular hour to use the system
# * 8AM and 6 PM (rush hour: commuting times)
# * 2PM (perhaps when school ends)

# %%
fig, axs = plt.subplots(ncols=6, figsize=(35, 3), sharey=True)
for i in range(len(years)):
    sns.countplot(x="Start_Hour", data=years_df[i], ax=axs[i])
    axs[i].set_title(years[i])
plt.show()

# %% [markdown]
# Hour distribution by day of the week

# %%
fig, axs = plt.subplots(nrows=7, ncols=6, figsize=(35, 25), sharex=True, sharey=False)
for i in range(len(years)):
    for j in range(len(weekday_name)):        
        sns.countplot(x="Start_Hour", 
                      data=years_df[i][years_df[i].Start_Weekday == weekday_name[j]], 
                      ax=axs[j,i])
        axs[j,i].set_title(weekday_name[j]+' ('+years[i]+')')
plt.show()

# %% [markdown]
# Trip duration by day of the week

# %%
# annual mean by week day
pd.DataFrame([[years_df[i][years_df[i]['Start_Weekday'] == weekday_name[j]]['Duration'].mean() for i in range(len(years))] \
              for j in range(len(weekday_name))],
             columns=years, index = weekday_name).round(2)
# Out:
#             2017   2018   2019   2020   2021   2022
# Monday     11.02  10.96  11.12  11.20  11.06  10.55
# Tuesday    11.02  11.00  11.12  11.28  11.06  10.56
# Wednesday  11.04  11.01  11.15  11.26  11.07  10.58
# Thursday   10.98  10.99  11.11  11.22  11.03  10.51
# Friday     11.03  11.03  11.16  11.25  11.04  10.55
# Saturday   11.09  11.04  11.22  11.36  11.15  10.66
# Sunday     13.60  13.21  13.26  12.37  12.96  12.83

# %%
# annual median by week day
pd.DataFrame([[years_df[i][years_df[i]['Start_Weekday'] == weekday_name[j]]['Duration'].median() for i in range(len(years))] \
              for j in range(len(weekday_name))],
             columns=years, index = weekday_name).round(2)
# Out:
#             2017   2018   2019   2020   2021   2022
# Monday      9.52   9.53   9.70   9.85   9.75   9.23
# Tuesday     9.53   9.60   9.75   9.93   9.73   9.25
# Wednesday   9.57   9.60   9.77   9.92   9.75   9.23
# Thursday    9.52   9.58   9.73   9.88   9.70   9.18
# Friday      9.52   9.62   9.75   9.88   9.68   9.22
# Saturday    9.52   9.57   9.72   9.92   9.73   9.20
# Sunday     10.78  10.57  10.67  10.22  10.67  10.30

# %% [markdown]
# ## Bike Stations

# %% [markdown]
# ### Start Stations

# %% [markdown]
# Create a table of the most popular starting stations and the most popular neighborhoods to start a trip

# %%
pd.concat([
MiBici2017.groupby(["Start_Name"]).size().reset_index(name = "Count").sort_values("Count", ascending = False).reset_index(drop=True).head(15),
MiBici2017.groupby(["Start_Neighborhood"]).size().reset_index(name = "Count").sort_values("Count", ascending = False).reset_index(drop=True).head(15)
], axis=1)
# Out:
#                               Start_Name  Count   Start_Neighborhood   Count
# 0      Lopez Cotilla/ Marcos Castellanos  48794            Americana  391154
# 1    C. Constancio Hernández/ Av. Juaréz  46553     Capilla de Jesús  208691
# 2    C. Pedro Moreno / Calz. Federalismo  42026   Guadalajara Centro  199751
# 3        Calz. Federalismo/ C. J. Angulo  37779       Arcos Vallarta  187757
# 4           Av. La Paz / Av. Federalismo  36816               Obrera  167362
# 5      Av. Juárez / Av. 16 de Septiembre  32672           Santa Tere  163014
# 6       Av. Juárez / Calz. Independencia  30967   Las Nueve Esquinas  148610
# 7     Av. 16 de Sept. / C. Miguel Blanco  28832        Mexicaltzingo   94646
# 8         C. Marsella / C. López Cotilla  28806    Mezquitán Country   72237
# 9            Av. Hidalgo / C. Pedro Loza  28567  Centro Barranquitas   63398
# 10       Calzada Federalismo / C. Vidrio  28179           Villaseñor   58521
# 11       Av. Vallarta / Av. de Los Arcos  26997    Ladrón de Guevara   54901
# 12            C. Degollado / Av. Hidalgo  26670            La Normal   43265
# 13       C. Colonias  / C. López Cotilla  26508     San Juan de Dios   38460
# 14            C. Juan Álvarez / C. Belén  26487  Barrio de Mezquitán   37802

# %% [markdown]
# ### End Stations

# %% [markdown]
# Create a table of the most popular ending stations and neighborhoods

# %%
pd.concat([
MiBici2017.groupby(["End_Name"]).size().reset_index(name = "Count").sort_values("Count", ascending = False).reset_index(drop=True).head(15),
MiBici2017.groupby(["End_Neighborhood"]).size().reset_index(name = "Count").sort_values("Count", ascending = False).reset_index(drop=True).head(15)
], axis=1)
# Out:
#                                 End_Name  Count     End_Neighborhood   Count
# 0      Lopez Cotilla/ Marcos Castellanos  59359            Americana  391882
# 1    C. Constancio Hernández/ Av. Juaréz  50085   Guadalajara Centro  224439
# 2    C. Pedro Moreno / Calz. Federalismo  43248     Capilla de Jesús  205958
# 3       Av. Juárez / Calz. Independencia  37787   Las Nueve Esquinas  180356
# 4      Av. Juárez / Av. 16 de Septiembre  37131               Obrera  154892
# 5        Calz. Federalismo/ C. J. Angulo  34747           Santa Tere  153846
# 6           Av. La Paz / Av. Federalismo  33761       Arcos Vallarta  146582
# 7             C. Degollado / Av. Hidalgo  33715        Mexicaltzingo   97089
# 8            Av. Hidalgo / C. Pedro Loza  32579  Centro Barranquitas   72260
# 9     Av. 16 de Sept. / C. Miguel Blanco  31451    Mezquitán Country   71792
# 10        C. Marsella / C. López Cotilla  29212           Villaseñor   52927
# 11               C. Comercio / C. La Paz  28739            La Normal   52446
# 12       Calzada Federalismo / C. Vidrio  28603     San Juan de Dios   45218
# 13            C. Juan Álvarez / C. Belén  27708    Ladrón de Guevara   45154
# 14     C. Marcos Castellanos/ C. Morelos  27093  Barrio de Mezquitán   42664

# %% [markdown]
# ### Most Popular Routes

# %% [markdown]
# Create dropdown table to see most popular routes per year

# %%
MiBici2017.groupby(["Start_Name","End_Name"]).size().reset_index(name = "Number of Trips").sort_values("Number of Trips", ascending = False).reset_index(drop=True).head(15)
# Out:
#                               Start_Name  \
# 0             C. Juan Álvarez / C. Belén
# 1             C. Juan Álvarez / C. Belén
# 2    C. Miguel Blanco / C. Penitenciaria
# 3      Lopez Cotilla/ Marcos Castellanos
# 4         C. Marsella / C. López Cotilla
# 5        C. Colonias  / C. López Cotilla
# 6      Lopez Cotilla/ Marcos Castellanos
# 7        Calz. Federalismo/ C. J. Angulo
# 8    C. Monte Cáucaso / C. Sierra Nevada
# 9       Av. Juárez / Calz. Independencia
# 10   C. Epigmenio Glez./Av. Cristobal C.
# 11   C. J. Angulo/C José Clemente Orozco
# 12     Lopez Cotilla/ Marcos Castellanos
# 13     Av. Juárez / Av. 16 de Septiembre
# 14       C. Montenegro / Av. Chapultepec
#
#                                 End_Name  Number of Trips
# 0             C. Juan Álvarez / C. Belén             2953
# 1    C. Monte Cáucaso / C. Sierra Nevada             2745
# 2    C. Miguel Blanco / C. Penitenciaria             2477
# 3      Lopez Cotilla/ Marcos Castellanos             2414
# 4      Lopez Cotilla/ Marcos Castellanos             2328
# 5      Lopez Cotilla/ Marcos Castellanos             2226
# 6        C. Colonias  / C. López Cotilla             2216
# 7             C. Juan Álvarez / C. Belén             2155
# 8             C. Juan Álvarez / C. Belén             2110
# 9      Av. Juárez / Av. 16 de Septiembre             1995
# 10   C. Epigmenio Glez./Av. Cristobal C.             1967
# 11       Calz. Federalismo/ C. J. Angulo             1905
# 12          Av. La Paz / Av. Federalismo             1828
# 13      Av. Juárez / Calz. Independencia             1751
# 14       C. Montenegro / Av. Chapultepec             1703

# %% [markdown]
# # Combine & Export Annual Data

# %%
# pd.concat(years_df, axis=0).to_csv("../../MiBici_Data/full_dataset.csv", index=False, encoding = 'utf-8')

# %%
# export data
# MiBici2017.to_csv('../../MiBici_Data/MiBici2017.csv', index=False, encoding = 'utf-8')
# MiBici2018.to_csv('../../MiBici_Data/MiBici2018.csv', index=False, encoding = 'utf-8')
# MiBici2019.to_csv('../../MiBici_Data/MiBici2019.csv', index=False, encoding = 'utf-8')
# MiBici2020.to_csv('../../MiBici_Data/MiBici2020.csv', index=False, encoding = 'utf-8')
# MiBici2021.to_csv('../../MiBici_Data/MiBici2021.csv', index=False, encoding = 'utf-8')
# MiBici2022.to_csv('../../MiBici_Data/MiBici2022.csv', index=False, encoding = 'utf-8')

# %%
# import data
MiBici2017 = pd.read_csv('../../MiBici_Data/MiBici2017.csv', encoding='utf-8')
MiBici2018 = pd.read_csv('../../MiBici_Data/MiBici2018.csv', encoding='utf-8')
MiBici2019 = pd.read_csv('../../MiBici_Data/MiBici2019.csv', encoding='utf-8')
MiBici2020 = pd.read_csv('../../MiBici_Data/MiBici2020.csv', encoding='utf-8')
MiBici2021 = pd.read_csv('../../MiBici_Data/MiBici2021.csv', encoding='utf-8')
MiBici2022 = pd.read_csv('../../MiBici_Data/MiBici2022.csv', encoding='utf-8')

# %%
years_df = [MiBici2017, MiBici2018, MiBici2019, MiBici2020, MiBici2021, MiBici2022]
years = ['2017', '2018', '2019', '2020', '2021', '2022']
weekday_name = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']

# %%
# delete when clean full jupyter notebook
MiBici2022 = MiBici2022[MiBici2022.Duration <= MiBici2022.Duration.quantile(.998)]
MiBici2022 = MiBici2022[MiBici2022.Duration >= 1.5]

# %% [markdown]
# # Research Questions

# %% [markdown]
# The goal of this section is to create smaller datasets that answer each research question

# %% [markdown]
# ## 1) Trips vs COVID

# %% [markdown]
# ### Weather Data

# %% [markdown]
# **NOAA/NCEI U.S. Climate Division Data:**
#
# [Climate Data Online](https://www.ncei.noaa.gov/cdo-web/) provides free access to the National Climatic Data Center's archive of global historical weather and climate data in addition to station history information. These data include quality controlled daily, monthly, seasonal, and yearly measurements of temperature, precipitation, wind, and degree days as well as radar data and 30-year Climate Normals.

# %%
weather_df = pd.read_csv('../../MiBici_Data/Weather/NOAA_NCEI_Climate_1Jan2017_30Nov2022.csv', encoding='utf-8')

# %% [markdown]
# Clean up dataframe

# %%
# Drop uneeded columns
weather_df = weather_df.drop(['STATION', 'NAME'], axis=1)

# rename other columns
weather_df.rename(columns={'DATE': 'Date'}, inplace=True)

# Convert Date column to datetime variable
weather_df.Date = pd.to_datetime(weather_df.Date)

# Trim data so it starts on same day as bike daya
weather_df =  weather_df[weather_df.Date >= '2014-12-01']

# %%
weather_df
# Out:
#            Date  PRCP  TAVG  TMAX  TMIN
# 0    2017-01-03   0.0    69   NaN   NaN
# 1    2017-01-04   0.0    61  82.0  45.0
# 2    2017-01-10   0.0    57  76.0  39.0
# 3    2017-01-11   0.0    56   NaN   NaN
# 4    2017-01-12   0.0    60  80.0  40.0
# ...         ...   ...   ...   ...   ...
# 1934 2022-11-26   0.0    65  81.0  51.0
# 1935 2022-11-27   0.0    65  81.0  48.0
# 1936 2022-11-28   0.0    67  81.0  48.0
# 1937 2022-11-29   0.0    65  83.0  48.0
# 1938 2022-11-30   0.0    65  82.0  47.0
#
# [1939 rows x 5 columns]

# %% [markdown]
# Plot daily average temperature (F) in Guadalajara

# %%
fig, ax = plt.subplots(figsize=(20, 6))

#weather_df.TAVG.plot(label="Avg Temp (F)", legend=True)
plt.plot(weather_df.Date, weather_df.TAVG)

plt.title('Average Temperature (F)')
plt.show()

# %% [markdown]
# Plot daily precipitation

# %%
fig, ax = plt.subplots(figsize=(20, 6))
plt.plot(weather_df.Date, weather_df.PRCP)
plt.title('Precipitation (in)')
# Out:
# Text(0.5, 1.0, 'Precipitation (in)')

# %%
fig, ax = plt.subplots(figsize=(20, 6))

y = [0]*len(weather_df.PRCP)
plt.scatter(weather_df.Date, y, s = weather_df.PRCP*100)
plt.title('Precipitation (in)')
# Out:
# Text(0.5, 1.0, 'Precipitation (in)')

# %% [markdown]
# Plot temperature & rainfall

# %%
fig, ax = plt.subplots(figsize=(20, 6))
y = [40]*len(weather_df.PRCP) 
plt.plot(weather_df.Date, weather_df.TAVG)   # BLUE LINE
plt.scatter(weather_df.Date, y, s = weather_df.PRCP*100, color='red', edgecolor='black')  # RED DOT

# %% [markdown]
# Add a column for prcp x axis values

# %%
weather_df.insert(2, "X_PRCP", [40]*len(weather_df.PRCP), True)

# %%
weather_df
# Out:
#            Date  PRCP  X_PRCP  TAVG  TMAX  TMIN
# 0    2017-01-03   0.0      40    69   NaN   NaN
# 1    2017-01-04   0.0      40    61  82.0  45.0
# 2    2017-01-10   0.0      40    57  76.0  39.0
# 3    2017-01-11   0.0      40    56   NaN   NaN
# 4    2017-01-12   0.0      40    60  80.0  40.0
# ...         ...   ...     ...   ...   ...   ...
# 1934 2022-11-26   0.0      40    65  81.0  51.0
# 1935 2022-11-27   0.0      40    65  81.0  48.0
# 1936 2022-11-28   0.0      40    67  81.0  48.0
# 1937 2022-11-29   0.0      40    65  83.0  48.0
# 1938 2022-11-30   0.0      40    65  82.0  47.0
#
# [1939 rows x 6 columns]

# %% [markdown]
# Export data

# %%
# weather_df.to_csv('../../MiBici_Data/Weather/NOAA_NCEI_Climate_1Jan2017_30Nov2022_clean.csv', index = False, encoding='utf-8')
# weather_df.to_csv('../../MiBici_Data/Tableau_Datasets/Question_1/NOAA_NCEI_Climate_1Jan2017_30Nov2022_clean.csv', index = False, encoding='utf-8')

# %% [markdown]
# ### COVID Data

# %% [markdown]
# **Gobierno de México:**
#
# The general directive of epidemiology for the Mexican government maintains a [dashboard](https://datos.covid-19.conacyt.mx/) of COVID-19 data for the country. In this analysis, the daily count of confirmed cases is used for the municipalities of interest.

# %% [markdown]
# Read in the COVID data that contains the daily cases per municipality.

# %%
covid_df = pd.read_csv('../../MiBici_Data/COVID/Casos_Diarios_Municipio_Confirmados_20221207.csv', encoding='utf-8')

# %% [markdown]
# Select the appropriate data for the municipalities.

# %%
covid_df = covid_df.loc[covid_df.nombre.isin(['Guadalajara', 'Zapopan', 'San Pedro Tlaquepaque'])].T

# %% [markdown]
# Clean up COVID dataframe

# %%
# Make the row indicies into a new column
covid_df.reset_index(inplace=True)

# drop the first two rows
covid_df.drop([0,1], inplace=True)

# replace the column names
covid_df = covid_df.rename(columns = covid_df.iloc[0]).drop(covid_df.index[0])

# rename other columns
covid_df.rename(columns={'nombre': 'Date', 'San Pedro Tlaquepaque': 'Tlaquepaque'}, inplace=True)

# Convert Date column to datetime variable
covid_df.Date = pd.to_datetime(covid_df.Date)

# Reset index
covid_df.reset_index(drop=True, inplace=True)

# Create new column of cases across all municipalities
covid_df['Total'] = covid_df[['Zapopan', 'Guadalajara', 'Tlaquepaque']].sum(axis=1)

# %%
covid_df
# Out:
#            Date Zapopan Guadalajara Tlaquepaque  Total
# 0    2020-02-26       0           0           0    0.0
# 1    2020-02-27       0           0           0    0.0
# 2    2020-02-28       0           0           0    0.0
# 3    2020-02-29       0           0           0    0.0
# 4    2020-03-01       0           0           0    0.0
# ...         ...     ...         ...         ...    ...
# 1011 2022-12-03       2           6           1    9.0
# 1012 2022-12-04       2          16           0   18.0
# 1013 2022-12-05      20          21           5   46.0
# 1014 2022-12-06       1           7           0    8.0
# 1015 2022-12-07       0           0           0    0.0
#
# [1016 rows x 5 columns]

# %% [markdown]
# Plot COVID cases by municipality

# %%
fig, ax = plt.subplots(figsize=(20, 6))

covid_df.Zapopan.plot(label="Zapopan", legend=True)
covid_df.Guadalajara.plot(label="Guadalajara", legend=True)
covid_df.Tlaquepaque.plot(label="Tlaquepaque", legend=True)
covid_df.Total.plot(label="Total", legend=True)

plt.show()

# %%
# Create temp dataframe of zeros for COVID data before first data collection '2020-02-25'
# to later append to true covid data
temp_df = pd.DataFrame({'Date': pd.date_range('2017-01-01', '2020-02-25', freq='D'),
                        'Zapopan': [0]*len(pd.date_range('2017-01-01', '2020-02-25', freq='D')),
                        'Guadalajara': [0]*len(pd.date_range('2017-01-01', '2020-02-25', freq='D')),
                        'Tlaquepaque': [0]*len(pd.date_range('2017-01-01', '2020-02-25', freq='D')),
                        'Total': [0]*len(pd.date_range('2017-01-01', '2020-02-25', freq='D')),
                       })

# %%
temp_df
# Out:
#            Date  Zapopan  Guadalajara  Tlaquepaque  Total
# 0    2017-01-01        0            0            0      0
# 1    2017-01-02        0            0            0      0
# 2    2017-01-03        0            0            0      0
# 3    2017-01-04        0            0            0      0
# 4    2017-01-05        0            0            0      0
# ...         ...      ...          ...          ...    ...
# 1146 2020-02-21        0            0            0      0
# 1147 2020-02-22        0            0            0      0
# 1148 2020-02-23        0            0            0      0
# 1149 2020-02-24        0            0            0      0
# 1150 2020-02-25        0            0            0      0
#
# [1151 rows x 5 columns]

# %%
# concatenate temp data to COVID data
covid_df = pd.concat([temp_df, covid_df], axis=0)

# %%
# Reset indicies
covid_df.reset_index(drop=True, inplace=True)

# %%
# PLot new dataframe
fig, ax = plt.subplots(figsize=(20, 6))

covid_df.Zapopan.plot(label="Zapopan", legend=True)
covid_df.Guadalajara.plot(label="Guadalajara", legend=True)
covid_df.Tlaquepaque.plot(label="Tlaquepaque", legend=True)
covid_df.Total.plot(label="Total", legend=True)

plt.show()

# %% [markdown]
# Convert data frame to long format for Tableau

# %%
covid_long_df = pd.melt(covid_df, id_vars='Date', value_vars=['Total', 'Guadalajara', 'Tlaquepaque', 'Zapopan'])

# %%
covid_long_df
# Out:
#            Date variable value
# 0    2017-01-01    Total   0.0
# 1    2017-01-02    Total   0.0
# 2    2017-01-03    Total   0.0
# 3    2017-01-04    Total   0.0
# 4    2017-01-05    Total   0.0
# ...         ...      ...   ...
# 8663 2022-12-03  Zapopan     2
# 8664 2022-12-04  Zapopan     2
# 8665 2022-12-05  Zapopan    20
# 8666 2022-12-06  Zapopan     1
# 8667 2022-12-07  Zapopan     0
#
# [8668 rows x 3 columns]

# %% [markdown]
# Export data

# %%
#covid_df.to_csv('../../MiBici_Data/COVID/COVID_daily_cases_clean_07122022.csv', index=False, encoding='utf-8')
#covid_df.to_csv('../../MiBici_Data/Tableau_Datasets/Question_1/COVID_daily_cases_clean_07122022.csv', index=False, encoding='utf-8')

#covid_long_df.to_csv('../../MiBici_Data/COVID/COVID_daily_cases_clean_long_07122022.csv', index=False, encoding='utf-8')
#covid_long_df.to_csv('../../MiBici_Data/Tableau_Datasets/Question_1/COVID_daily_cases_clean_long_07122022.csv', index=False, encoding='utf-8')

# %% [markdown]
# ### Daily Bike Trip Counts

# %%
# Loop through each file, save as dataframe, and obtain the row count for 2017-2021
output = pd.Series(name="Rows", dtype=int)

for file in years_df:
    df = file
    df['Start_Time'] = pd.to_datetime(df['Start_Time']).dt.strftime('%Y-%m-%d')
    output = pd.concat([output,df.groupby(['Start_City', 'Start_Time']).count().iloc[:,0]], axis=0)

# %%
output
# Out:
# (Guadalajara, 2017-01-01)    1172
# (Guadalajara, 2017-01-02)    3725
# (Guadalajara, 2017-01-03)    4465
# (Guadalajara, 2017-01-04)    4717
# (Guadalajara, 2017-01-05)    4947
#                              ...
# (Zapopan, 2022-10-27)        1316
# (Zapopan, 2022-10-28)        1249
# (Zapopan, 2022-10-29)         751
# (Zapopan, 2022-10-30)         581
# (Zapopan, 2022-10-31)        1288
# Length: 6390, dtype: int64

# %% [markdown]
# Turn output into a formatted data frame for Tableau

# %%
# turn 'output' to dataframe
output_df = pd.DataFrame(output).reset_index(drop=False)

# spilt tuple into two columns of df and concat to output_df
output_df = pd.concat([output_df, 
                       pd.DataFrame(output_df['index'].tolist(), columns=['Region', 'Date'])
                      ], axis = 1)
           
# delete extra unformated tuple column
output_df.drop('index', axis=1, inplace=True)

# rename columns
output_df.columns = ['Count', 'Region', 'Date']

# conver Date column into datetime
output_df.Date = pd.to_datetime(output_df.Date)

# %%
output_df
# Out:
#       Count       Region        Date
# 0      1172  Guadalajara  2017-01-01
# 1      3725  Guadalajara  2017-01-02
# 2      4465  Guadalajara  2017-01-03
# 3      4717  Guadalajara  2017-01-04
# 4      4947  Guadalajara  2017-01-05
# ...     ...          ...         ...
# 6385   1316      Zapopan  2022-10-27
# 6386   1249      Zapopan  2022-10-28
# 6387    751      Zapopan  2022-10-29
# 6388    581      Zapopan  2022-10-30
# 6389   1288      Zapopan  2022-10-31
#
# [6390 rows x 3 columns]

# %%
# add category for the total # trips across all regions
temp_df = pd.DataFrame(output_df.groupby(['Date'])['Count'].sum()).reset_index()
temp_df['Region'] = ['Total']*len(temp_df)

# rearrange order of columns
temp_df = temp_df.reindex(columns=['Count', 'Region', 'Date'])
# Out:
#             Date  Count Region
# 0     2017-01-01   1291  Total
# 1     2017-01-02   3991  Total
# 2     2017-01-03   4775  Total
# 3     2017-01-04   5044  Total
# 4     2017-01-05   5277  Total
# ...          ...    ...    ...
# 2125  2022-10-27  14845  Total
# 2126  2022-10-28  14557  Total
# 2127  2022-10-29   9990  Total
# 2128  2022-10-30   7938  Total
# 2129  2022-10-31  14501  Total
#
# [2130 rows x 3 columns]

# %% [markdown]
# Combine two dataframes to export

# %%
output_df = pd.concat([output_df, temp_df], axis=0).reset_index(drop=True)

# %% [markdown]
# Export data

# %%
# output_df.to_csv('../../MiBici_Data/Tableau_Datasets/Question_1/daily_trip_count.csv', index=False, encoding='utf-8')

# %% [markdown]
# ## 2) Trip Duration

# %% [markdown]
# ### Summary Statistics

# %%
# Summary Statistics
pd.concat([MiBici2017.Duration.describe().apply(lambda x: '%.2f' % x),
           MiBici2018.Duration.describe().apply(lambda x: '%.2f' % x),
           MiBici2019.Duration.describe().apply(lambda x: '%.2f' % x),
           MiBici2020.Duration.describe().apply(lambda x: '%.2f' % x),
           MiBici2021.Duration.describe().apply(lambda x: '%.2f' % x),
           MiBici2022.Duration.describe().apply(lambda x: '%.2f' % x)
          ], axis=1)
# Out:
#          Duration    Duration    Duration    Duration    Duration    Duration
# count  2445638.00  3299857.00  4480232.00  2758939.00  3053133.00  3320130.00
# mean        11.23       11.18       11.31       11.34       11.23       11.16
# std          7.19        6.82        6.85        6.77        6.69        6.67
# min          1.50        1.50        1.50        1.50        1.50        1.50
# 25%          6.08        6.10        6.17        6.20        6.12        6.07
# 50%          9.62        9.65        9.80        9.92        9.80        9.70
# 75%         14.78       14.75       14.98       15.07       14.95       14.87
# max        100.62       62.55       58.40       51.93       46.47       45.65

# %%
summary_avg_duration_df = \
pd.concat([MiBici2017.Duration.describe().apply(lambda x: '%.2f' % x),
           MiBici2018.Duration.describe().apply(lambda x: '%.2f' % x),
           MiBici2019.Duration.describe().apply(lambda x: '%.2f' % x),
           MiBici2020.Duration.describe().apply(lambda x: '%.2f' % x),
           MiBici2021.Duration.describe().apply(lambda x: '%.2f' % x),
           MiBici2022.Duration.describe().apply(lambda x: '%.2f' % x)
          ], axis=1, keys = years).T

# %%
summary_avg_duration_df
# Out:
#            count   mean   std   min   25%   50%    75%     max
# 2017  2445638.00  11.23  7.19  1.50  6.08  9.62  14.78  100.62
# 2018  3299857.00  11.18  6.82  1.50  6.10  9.65  14.75   62.55
# 2019  4480232.00  11.31  6.85  1.50  6.17  9.80  14.98   58.40
# 2020  2758939.00  11.34  6.77  1.50  6.20  9.92  15.07   51.93
# 2021  3053133.00  11.23  6.69  1.50  6.12  9.80  14.95   46.47
# 2022  3320130.00  11.16  6.67  1.50  6.07  9.70  14.87   45.65

# %%
# export sumary stats
summary_avg_duration_df.to_csv('../../MiBici_Data/Tableau_Datasets/Question_2/Summary_Stat_Trip_Duration.csv', encoding = 'utf-8')

# %%
# Loop through each dataset and create its plot
fig, axs = plt.subplots(ncols=6, figsize=(40, 5), sharey=True)
for i in range(len(years)):
    sns.histplot(years_df[i]['Duration'], bins=range(0,150,1), ax=axs[i])
    axs[i].set_title(years[i])
plt.show()

# %%
fig, axs = plt.subplots(figsize=(15, 5))

MiBici2017.groupby(pd.to_datetime(MiBici2017['Start_Time']).dt.date)['Duration'].mean().plot()
MiBici2018.groupby(pd.to_datetime(MiBici2018['Start_Time']).dt.date)['Duration'].mean().plot()
MiBici2019.groupby(pd.to_datetime(MiBici2019['Start_Time']).dt.date)['Duration'].mean().plot()
MiBici2020.groupby(pd.to_datetime(MiBici2020['Start_Time']).dt.date)['Duration'].mean().plot()
MiBici2021.groupby(pd.to_datetime(MiBici2021['Start_Time']).dt.date)['Duration'].mean().plot()
MiBici2022.groupby(pd.to_datetime(MiBici2022['Start_Time']).dt.date)['Duration'].mean().plot()

plt.ylim([0, 15])

plt.show()

# %% [markdown]
# ### Daily Avg Trip Dur

# %%
avg_duration_df = pd.DataFrame(pd.concat([years_df[i].groupby(pd.to_datetime(years_df[i]['Start_Time']).dt.to_period('M'))['Duration'].mean() \
                                          for i in range(len(years))
                                         ], axis=0)
                              )

# %%
avg_duration_df = pd.DataFrame(pd.concat([years_df[i].groupby(pd.to_datetime(years_df[i]['Start_Time']).dt.date)['Duration'].mean() \
                                          for i in range(len(years))
                                         ], axis=0)
                              )

# %%
avg_duration_df
# Out:
#              Duration
# Start_Time
# 2017-01     11.526349
# 2017-02     11.481496
# 2017-03     11.340221
# 2017-04     11.310738
# 2017-05     11.062440
# ...               ...
# 2022-06     10.700783
# 2022-07     10.789026
# 2022-08     10.752939
# 2022-09     10.854185
# 2022-10     10.866390
#
# [70 rows x 1 columns]

# %%
fig, axs = plt.subplots(figsize=(15, 5))
avg_duration_df.Duration.plot()
plt.ylim([0, 15])
plt.show()

# %%
avg_duration_df.reset_index(drop=False, inplace=True)

# %%
avg_duration_df['Year'] = avg_duration_df.Start_Time.astype('str').str.split('-', expand = True, n=1).loc[:,0]

# %%
avg_duration_df
# Out:
#       Start_Time   Duration  Year
# 0     2017-01-01  14.254480  2017
# 1     2017-01-02  11.248551  2017
# 2     2017-01-03  11.346600  2017
# 3     2017-01-04  11.572429  2017
# 4     2017-01-05  11.502334  2017
# ...          ...        ...   ...
# 2125  2022-10-27  10.501305  2022
# 2126  2022-10-28  10.584671  2022
# 2127  2022-10-29  10.845736  2022
# 2128  2022-10-30  12.478322  2022
# 2129  2022-10-31  10.709609  2022
#
# [2130 rows x 3 columns]

# %%
# avg_duration_df.to_csv('../../MiBici_Data/Tableau_Datasets/Question_2/DailyAvgTrip_Duration.csv', encoding = 'utf-8')

# %% [markdown]
# ## 3) Trips per Hour

# %% [markdown]
# ### Avg Workweek vs Weekend

# %% [markdown]
# The goal is to determine the average number of trips taken at each hour of the day over the 6 years worth of data.
# * The data is split into workdays (M-F) and weekends (Sat/Sun)

# %% [markdown]
# #### Weekend

# %% [markdown]
# Calculate the total # of trips per hour for each year

# %%
Avg_weekend_df = pd.DataFrame([years_df[i].loc[(years_df[i]['Start_Weekday'] == 'Saturday') | (years_df[i]['Start_Weekday'] == 'Sunday')].groupby('Start_Hour').size()   \
              for i in range(len(years)) 
             ], index=years).T

# %% [markdown]
# Sum across each row to get the total # trips over all 6 years

# %%
Avg_weekend_df['Sum'] = Avg_weekend_df.sum(axis=1)

# %%
Avg_weekend_df
# Out:
#                2017     2018     2019     2020     2021     2022       Sum
# Start_Hour
# 0               2.0      5.0     11.0      7.0   5322.0   8735.0   14082.0
# 1               NaN      NaN      NaN      NaN      3.0      2.0       5.0
# 5               NaN      NaN      1.0      NaN   1637.0   2766.0    4404.0
# 6            4547.0   6583.0   9977.0   7548.0   7549.0   8899.0   45103.0
# 7            9007.0  13447.0  20125.0  14724.0  16508.0  19131.0   92942.0
# 8           18852.0  27681.0  39060.0  24244.0  28139.0  33686.0  171662.0
# 9           23983.0  34961.0  47747.0  29431.0  35185.0  42847.0  214154.0
# 10          29458.0  40989.0  56615.0  34904.0  41912.0  51115.0  254993.0
# 11          35028.0  47806.0  64649.0  39674.0  47110.0  56554.0  290821.0
# 12          39257.0  53236.0  70577.0  42949.0  50256.0  60467.0  316742.0
# 13          41407.0  57405.0  75889.0  47818.0  54236.0  63949.0  340704.0
# 14          37375.0  53382.0  71898.0  47639.0  52715.0  60482.0  323491.0
# 15          29983.0  42852.0  57758.0  39523.0  44373.0  49703.0  264192.0
# 16          24478.0  34985.0  47346.0  31826.0  36005.0  40633.0  215273.0
# 17          22748.0  33197.0  44175.0  29775.0  32844.0  37480.0  200219.0
# 18          23900.0  32871.0  43771.0  30874.0  33912.0  37330.0  202658.0
# 19          23678.0  33013.0  45576.0  30378.0  34228.0  38279.0  205152.0
# 20          22547.0  31330.0  42960.0  28177.0  31489.0  37515.0  194018.0
# 21          19813.0  27280.0  37311.0  22687.0  27069.0  31544.0  165704.0
# 22          14133.0  19382.0  25396.0  13562.0  16787.0  21021.0  110281.0
# 23           9020.0  11587.0  14868.0   7316.0   8974.0  11268.0   63033.0

# %% [markdown]
# Divide the `Sum` column by the number of weekend over the 6 years to get the average.
# * There are 52 weeks in a year and 2 days in a weekend.
# * I assume that each year is the same so 52*2 = 104 days
# * Since there is no November/December 2022 data, I subtract 8*2 = 16 from the total

# %%
Avg_weekend_df['Avg'] = Avg_weekend_df['Sum']/(104*6-16)

# %%
Avg_weekend_df
# Out:
#                2017     2018     2019     2020     2021     2022       Sum  \
# Start_Hour
# 0               2.0      5.0     11.0      7.0   5322.0   8735.0   14082.0
# 1               NaN      NaN      NaN      NaN      3.0      2.0       5.0
# 5               NaN      NaN      1.0      NaN   1637.0   2766.0    4404.0
# 6            4547.0   6583.0   9977.0   7548.0   7549.0   8899.0   45103.0
# 7            9007.0  13447.0  20125.0  14724.0  16508.0  19131.0   92942.0
# 8           18852.0  27681.0  39060.0  24244.0  28139.0  33686.0  171662.0
# 9           23983.0  34961.0  47747.0  29431.0  35185.0  42847.0  214154.0
# 10          29458.0  40989.0  56615.0  34904.0  41912.0  51115.0  254993.0
# 11          35028.0  47806.0  64649.0  39674.0  47110.0  56554.0  290821.0
# 12          39257.0  53236.0  70577.0  42949.0  50256.0  60467.0  316742.0
# 13          41407.0  57405.0  75889.0  47818.0  54236.0  63949.0  340704.0
# 14          37375.0  53382.0  71898.0  47639.0  52715.0  60482.0  323491.0
# 15          29983.0  42852.0  57758.0  39523.0  44373.0  49703.0  264192.0
# 16          24478.0  34985.0  47346.0  31826.0  36005.0  40633.0  215273.0
# 17          22748.0  33197.0  44175.0  29775.0  32844.0  37480.0  200219.0
# 18          23900.0  32871.0  43771.0  30874.0  33912.0  37330.0  202658.0
# 19          23678.0  33013.0  45576.0  30378.0  34228.0  38279.0  205152.0
# 20          22547.0  31330.0  42960.0  28177.0  31489.0  37515.0  194018.0
# 21          19813.0  27280.0  37311.0  22687.0  27069.0  31544.0  165704.0
# 22          14133.0  19382.0  25396.0  13562.0  16787.0  21021.0  110281.0
# 23           9020.0  11587.0  14868.0   7316.0   8974.0  11268.0   63033.0
#
#                    Avg
# Start_Hour
# 0            23.161184
# 1             0.008224
# 5             7.243421
# 6            74.182566
# 7           152.865132
# 8           282.338816
# 9           352.226974
# 10          419.396382
# 11          478.324013
# 12          520.957237
# 13          560.368421
# 14          532.057566
# 15          434.526316
# 16          354.067434
# 17          329.307566
# 18          333.319079
# 19          337.421053
# 20          319.108553
# 21          272.539474
# 22          181.383224
# 23          103.672697

# %%
Avg_weekend_df['Avg'].plot()
# Out:
# <AxesSubplot:xlabel='Start_Hour'>

# %% [markdown]
# #### Work Week

# %% [markdown]
# Calculate the total # of trips per hour for each year

# %%
Avg_workweek_df = pd.DataFrame([years_df[i].loc[(years_df[i]['Start_Weekday'] != 'Saturday') & (years_df[i]['Start_Weekday'] != 'Sunday')].groupby('Start_Hour').size()   \
              for i in range(len(years)) 
             ], index=years).T

# %% [markdown]
# Sum across each row to get the total # trips over all 6 years

# %%
Avg_workweek_df['Sum'] = Avg_workweek_df.sum(axis=1)

# %%
Avg_workweek_df
# Out:
#                 2017      2018      2019      2020      2021      2022  \
# Start_Hour
# 0               11.0      11.0      24.0       4.0    7733.0   11020.0
# 1                3.0       1.0       NaN       NaN       4.0       2.0
# 2                NaN       1.0       NaN       NaN       NaN       NaN
# 4                NaN       NaN       3.0       NaN       NaN       NaN
# 5                1.0       NaN      18.0       1.0    8237.0   14480.0
# 6            45864.0   63763.0   93037.0   52065.0   54417.0   73378.0
# 7            94486.0  129304.0  186744.0  104173.0  115220.0  147513.0
# 8           167202.0  226221.0  308704.0  169625.0  191835.0  227472.0
# 9           118729.0  158921.0  206402.0  133417.0  145145.0  160087.0
# 10           90826.0  118870.0  161592.0  108601.0  112831.0  119816.0
# 11           87315.0  117194.0  155868.0  106698.0  110613.0  113840.0
# 12           97319.0  129770.0  172317.0  114222.0  114681.0  126184.0
# 13          112619.0  154566.0  212387.0  135737.0  139463.0  151045.0
# 14          141099.0  191171.0  257018.0  159380.0  162061.0  177261.0
# 15          134462.0  184072.0  251389.0  157513.0  168642.0  184391.0
# 16          117526.0  159253.0  223472.0  141747.0  154199.0  169718.0
# 17          132358.0  182610.0  259785.0  168784.0  186715.0  209648.0
# 18          204824.0  272408.0  376543.0  231416.0  258203.0  295734.0
# 19          184655.0  238670.0  308425.0  182769.0  203037.0  233715.0
# 20          120379.0  155732.0  209134.0  121553.0  137830.0  162590.0
# 21           88615.0  114066.0  153081.0   83510.0   97630.0  116729.0
# 22           51456.0   66759.0   86103.0   43726.0   53568.0   61652.0
# 23           26673.0   34502.0   42476.0   20942.0   24816.0   29517.0
#
#                   Sum
# Start_Hour
# 0             18803.0
# 1                10.0
# 2                 1.0
# 4                 3.0
# 5             22737.0
# 6            382524.0
# 7            777440.0
# 8           1291059.0
# 9            922701.0
# 10           712536.0
# 11           691528.0
# 12           754493.0
# 13           905817.0
# 14          1087990.0
# 15          1080469.0
# 16           965915.0
# 17          1139900.0
# 18          1639128.0
# 19          1351271.0
# 20           907218.0
# 21           653631.0
# 22           363264.0
# 23           178926.0

# %% [markdown]
# Divide the `Sum` column by the number of work weeks over the 6 years to get the average.
# * There are 52 weeks in a year and 5 days in a work week.
# * I assume that each year is the same so 52*5 = 260 days
# * Since there is no November/December 2022 data, I subtract 8*5 = 40 from the total

# %%
Avg_workweek_df['Avg'] = Avg_workweek_df['Sum']/(260*6-40)

# %%
Avg_workweek_df
# Out:
#                 2017      2018      2019      2020      2021      2022  \
# Start_Hour
# 0               11.0      11.0      24.0       4.0    7733.0   11020.0
# 1                3.0       1.0       NaN       NaN       4.0       2.0
# 2                NaN       1.0       NaN       NaN       NaN       NaN
# 4                NaN       NaN       3.0       NaN       NaN       NaN
# 5                1.0       NaN      18.0       1.0    8237.0   14480.0
# 6            45864.0   63763.0   93037.0   52065.0   54417.0   73378.0
# 7            94486.0  129304.0  186744.0  104173.0  115220.0  147513.0
# 8           167202.0  226221.0  308704.0  169625.0  191835.0  227472.0
# 9           118729.0  158921.0  206402.0  133417.0  145145.0  160087.0
# 10           90826.0  118870.0  161592.0  108601.0  112831.0  119816.0
# 11           87315.0  117194.0  155868.0  106698.0  110613.0  113840.0
# 12           97319.0  129770.0  172317.0  114222.0  114681.0  126184.0
# 13          112619.0  154566.0  212387.0  135737.0  139463.0  151045.0
# 14          141099.0  191171.0  257018.0  159380.0  162061.0  177261.0
# 15          134462.0  184072.0  251389.0  157513.0  168642.0  184391.0
# 16          117526.0  159253.0  223472.0  141747.0  154199.0  169718.0
# 17          132358.0  182610.0  259785.0  168784.0  186715.0  209648.0
# 18          204824.0  272408.0  376543.0  231416.0  258203.0  295734.0
# 19          184655.0  238670.0  308425.0  182769.0  203037.0  233715.0
# 20          120379.0  155732.0  209134.0  121553.0  137830.0  162590.0
# 21           88615.0  114066.0  153081.0   83510.0   97630.0  116729.0
# 22           51456.0   66759.0   86103.0   43726.0   53568.0   61652.0
# 23           26673.0   34502.0   42476.0   20942.0   24816.0   29517.0
#
#                   Sum          Avg
# Start_Hour
# 0             18803.0    12.370395
# 1                10.0     0.006579
# 2                 1.0     0.000658
# 4                 3.0     0.001974
# 5             22737.0    14.958553
# 6            382524.0   251.660526
# 7            777440.0   511.473684
# 8           1291059.0   849.380921
# 9            922701.0   607.040132
# 10           712536.0   468.773684
# 11           691528.0   454.952632
# 12           754493.0   496.376974
# 13           905817.0   595.932237
# 14          1087990.0   715.782895
# 15          1080469.0   710.834868
# 16           965915.0   635.470395
# 17          1139900.0   749.934211
# 18          1639128.0  1078.373684
# 19          1351271.0   888.994079
# 20           907218.0   596.853947
# 21           653631.0   430.020395
# 22           363264.0   238.989474
# 23           178926.0   117.714474

# %%
Avg_workweek_df['Avg'].plot()
# Out:
# <AxesSubplot:xlabel='Start_Hour'>

# %% [markdown]
# #### Combine Datasets & Export

# %%
pd.concat([Avg_workweek_df['Avg'], Avg_weekend_df['Avg']], axis=1, keys=['WorkWeek', 'Weekend'])
# Out:
#                WorkWeek     Weekend
# Start_Hour
# 0             12.370395   23.161184
# 1              0.006579    0.008224
# 2              0.000658         NaN
# 4              0.001974         NaN
# 5             14.958553    7.243421
# 6            251.660526   74.182566
# 7            511.473684  152.865132
# 8            849.380921  282.338816
# 9            607.040132  352.226974
# 10           468.773684  419.396382
# 11           454.952632  478.324013
# 12           496.376974  520.957237
# 13           595.932237  560.368421
# 14           715.782895  532.057566
# 15           710.834868  434.526316
# 16           635.470395  354.067434
# 17           749.934211  329.307566
# 18          1078.373684  333.319079
# 19           888.994079  337.421053
# 20           596.853947  319.108553
# 21           430.020395  272.539474
# 22           238.989474  181.383224
# 23           117.714474  103.672697

# %%
# pd.concat([Avg_workweek_df['Avg'], Avg_weekend_df['Avg']], axis=1, keys=['WorkWeek', 'Weekend']) \
# .to_csv('../../MiBici_Data/Tableau_Datasets/Question_3/AvgTrip_PerHour.csv', encoding = 'utf-8')

# %% [markdown]
# ### Circular HeatMap

# %% [markdown]
# Ultimate goal is to obtain a dataset that has the number trips per hour for every date (Y-m-d) in the dataset.

# %%
df_hourly = pd.DataFrame()
df_hourly['Date_Hr_Count'] = pd.concat([pd.to_datetime(MiBici2017.Start_Time),
                                        pd.to_datetime(MiBici2018.Start_Time),
                                        pd.to_datetime(MiBici2019.Start_Time),
                                        pd.to_datetime(MiBici2020.Start_Time),
                                        pd.to_datetime(MiBici2021.Start_Time),
                                        pd.to_datetime(MiBici2022.Start_Time)
                                       ], axis = 0)

# %%
df_hourly["Hr"]            = df_hourly["Date_Hr_Count"].dt.strftime("%H:00")
df_hourly['Date_Hr_Count'] = df_hourly["Date_Hr_Count"].dt.strftime("%Y-%m-%d %H:00")

# %%
df_hourly.sort_values('Date_Hr_Count', inplace = True)

# %%
df_hourly
# Out:
#             Date_Hr_Count     Hr
# 130406   2017-01-01 06:00  06:00
# 136419   2017-01-01 06:00  06:00
# 36754    2017-01-01 06:00  06:00
# 77582    2017-01-01 06:00  06:00
# 93473    2017-01-01 06:00  06:00
# ...                   ...    ...
# 3346409  2022-10-31 23:00  23:00
# 3313462  2022-10-31 23:00  23:00
# 3323550  2022-10-31 23:00  23:00
# 3219373  2022-10-31 23:00  23:00
# 3428202  2022-10-31 23:00  23:00
#
# [19536997 rows x 2 columns]

# %% [markdown]
# Obtain the number of rides per hour of each day

# %%
df_hr_count = pd.DataFrame()
df_hr_count = df_hourly.groupby(['Date_Hr_Count','Hr']).size()

# %%
df_hr_count = pd.DataFrame(df_hr_count, columns = ['Count'])
df_hr_count.reset_index(level=['Date_Hr_Count','Hr'], inplace=True)
df_hr_count
# Out:
#           Date_Hr_Count     Hr  Count
# 0      2017-01-01 06:00  06:00     11
# 1      2017-01-01 07:00  07:00     16
# 2      2017-01-01 08:00  08:00     22
# 3      2017-01-01 09:00  09:00     38
# 4      2017-01-01 10:00  10:00     67
# ...                 ...    ...    ...
# 39768  2022-10-31 19:00  19:00   1120
# 39769  2022-10-31 20:00  20:00    615
# 39770  2022-10-31 21:00  21:00    433
# 39771  2022-10-31 22:00  22:00    250
# 39772  2022-10-31 23:00  23:00    114
#
# [39773 rows x 3 columns]

# %%
df_hr_count.dtypes
# Out:
# Date_Hr_Count    object
# Hr               object
# Count             int64
# dtype: object

# %% [markdown]
# Find the hours per day that are misising from the dataframe. These will be added to the dataframe eventually with a count value of zero

# %%
pd.date_range(start = '2017-01-01 00:00', end = '2022-10-31 23:59', freq = 'H').difference(pd.to_datetime(df_hourly.Date_Hr_Count))
# Out:
# DatetimeIndex(['2017-01-01 00:00:00', '2017-01-01 01:00:00',
#                '2017-01-01 02:00:00', '2017-01-01 03:00:00',
#                '2017-01-01 04:00:00', '2017-01-01 05:00:00',
#                '2017-01-02 00:00:00', '2017-01-02 01:00:00',
#                '2017-01-02 02:00:00', '2017-01-02 03:00:00',
#                ...
#                '2022-10-29 03:00:00', '2022-10-29 04:00:00',
#                '2022-10-30 01:00:00', '2022-10-30 02:00:00',
#                '2022-10-30 03:00:00', '2022-10-30 04:00:00',
#                '2022-10-31 01:00:00', '2022-10-31 02:00:00',
#                '2022-10-31 03:00:00', '2022-10-31 04:00:00'],
#               dtype='datetime64[ns]', length=11347, freq=None)

# %%
df_missing_hrs = pd.DataFrame()
df_missing_hrs['Date_Hr_Count'] = pd.date_range(start = '2017-01-01 00:00', end = '2022-10-31 23:59', freq = 'H').difference(pd.to_datetime(df_hourly.Date_Hr_Count))

# %%
df_missing_hrs
# Out:
#             Date_Hr_Count
# 0     2017-01-01 00:00:00
# 1     2017-01-01 01:00:00
# 2     2017-01-01 02:00:00
# 3     2017-01-01 03:00:00
# 4     2017-01-01 04:00:00
# ...                   ...
# 11342 2022-10-30 04:00:00
# 11343 2022-10-31 01:00:00
# 11344 2022-10-31 02:00:00
# 11345 2022-10-31 03:00:00
# 11346 2022-10-31 04:00:00
#
# [11347 rows x 1 columns]

# %% [markdown]
# Create dataframe of missing hours in similar style of `df_hr_count` to concatenate the two

# %%
df_missing_hrs['Hr'] = df_missing_hrs['Date_Hr_Count'].dt.strftime("%H:00")
df_missing_hrs['Count'] = 0

# %%
# Export dataframe
# df_missing_hrs.to_csv('../../MiBici_Data/Tableau_Datasets/Question_3/missing_Radial_HeatMap.csv', index=False)

# %% [markdown]
# Combine the df_hr_count & df_missing_hrs dataframes

# %%
Radial_df = pd.concat([df_hr_count, df_missing_hrs], axis = 0)

# %% [markdown]
# Reformat for Tableau

# %%
# Turn Hr column to type integer
Radial_df['Hr'] = Radial_df['Hr'].apply(lambda x: int(x[:2]))

# %%
# Turn Date_Hr_Count column into type datetime 
Radial_df['Date_Hr_Count'] = pd.to_datetime(Radial_df['Date_Hr_Count'])

# %%
# sort dataframe by date
Radial_df.sort_values(by=['Date_Hr_Count'], ignore_index=True, inplace=True)

# %%
# Extract year from Date column and create new column 
Radial_df['Year'] = Radial_df['Date_Hr_Count'].dt.year

# %%
# Create a date column (Y-m-d)
Radial_df['Date'] = Radial_df.Date_Hr_Count.dt.date

# %%
Radial_df
# Out:
#             Date_Hr_Count  Hr  Count  Year        Date
# 0     2017-01-01 00:00:00   0      0  2017  2017-01-01
# 1     2017-01-01 01:00:00   1      0  2017  2017-01-01
# 2     2017-01-01 02:00:00   2      0  2017  2017-01-01
# 3     2017-01-01 03:00:00   3      0  2017  2017-01-01
# 4     2017-01-01 04:00:00   4      0  2017  2017-01-01
# ...                   ...  ..    ...   ...         ...
# 51115 2022-10-31 19:00:00  19   1120  2022  2022-10-31
# 51116 2022-10-31 20:00:00  20    615  2022  2022-10-31
# 51117 2022-10-31 21:00:00  21    433  2022  2022-10-31
# 51118 2022-10-31 22:00:00  22    250  2022  2022-10-31
# 51119 2022-10-31 23:00:00  23    114  2022  2022-10-31
#
# [51120 rows x 5 columns]

# %% [markdown]
# Add column `day_index` that indicates the day of the year for each date [1, 2, ..., 366]

# %%
Radial_df['day_index'] = Radial_df.Date_Hr_Count.dt.strftime('%j')

# %%
Radial_df
# Out:
#             Date_Hr_Count  Hr  Count  Year        Date day_index
# 0     2017-01-01 00:00:00   0      0  2017  2017-01-01       001
# 1     2017-01-01 01:00:00   1      0  2017  2017-01-01       001
# 2     2017-01-01 02:00:00   2      0  2017  2017-01-01       001
# 3     2017-01-01 03:00:00   3      0  2017  2017-01-01       001
# 4     2017-01-01 04:00:00   4      0  2017  2017-01-01       001
# ...                   ...  ..    ...   ...         ...       ...
# 51115 2022-10-31 19:00:00  19   1120  2022  2022-10-31       304
# 51116 2022-10-31 20:00:00  20    615  2022  2022-10-31       304
# 51117 2022-10-31 21:00:00  21    433  2022  2022-10-31       304
# 51118 2022-10-31 22:00:00  22    250  2022  2022-10-31       304
# 51119 2022-10-31 23:00:00  23    114  2022  2022-10-31       304
#
# [51120 rows x 6 columns]

# %%
# convert day_index from string to integer
Radial_df['day_index'] = Radial_df.day_index.astype('int')

# %%
# export data
# Radial_df.to_csv('../../MiBici_Data/Tableau_Datasets/Question_3/Radial_HeatMap.csv', index=False)

# %% [markdown]
# ## 4) Popular Routes

# %%
.size().reset_index(name = "size").sort_values("size", ascending = False).reset_index(drop=True).head(25)

# %% [markdown]
# ### Add/Neigh Tables

# %% [markdown]
# Find the most popular routes

# %%
# Loop through each file, temporarily save as dataframe
startEnd_df = pd.DataFrame()

for file in years_df:
    # obtain counts of start/end trip combos
    df = file.groupby(['Start_Name', 'End_Name']).size().reset_index(name = "size").sort_values("size", ascending = False).reset_index(drop=True).head(25)
    
    # Add Date to dataframe and turn into type datetime
    df['Date'] = pd.to_datetime(file['Start_Time'][0])
    df['Date'] = df['Date'].dt.strftime("%Y")
    
    # concatenate to full dataframe
    startEnd_df = pd.concat([startEnd_df, df], axis=0)

# %%
startEnd_df
# Out:
#                               Start_Name  \
# 0             C. Juan Álvarez / C. Belén
# 1             C. Juan Álvarez / C. Belén
# 2    C. Miguel Blanco / C. Penitenciaria
# 3      Lopez Cotilla/ Marcos Castellanos
# 4         C. Marsella / C. López Cotilla
# ..                                   ...
# 20     Lopez Cotilla/ Marcos Castellanos
# 21     C. Marcos Castellanos/ C. Morelos
# 22     Av. Aurelio Ortega / Av. Laureles
# 23   C. Duque de Rivas/ C. López Cotilla
# 24             Av. Alcalde / C. Hospital
#
#                                 End_Name  size  Date
# 0             C. Juan Álvarez / C. Belén  2953  2017
# 1    C. Monte Cáucaso / C. Sierra Nevada  2745  2017
# 2    C. Miguel Blanco / C. Penitenciaria  2477  2017
# 3      Lopez Cotilla/ Marcos Castellanos  2414  2017
# 4      Lopez Cotilla/ Marcos Castellanos  2328  2017
# ..                                   ...   ...   ...
# 20          Av. La Paz / Av. Federalismo  2566  2022
# 21              C. Morelos / C. Progreso  2525  2022
# 22       Av. Aurelio Ortega / C. Morelos  2487  2022
# 23     Lopez Cotilla/ Marcos Castellanos  2481  2022
# 24           Av. Hidalgo / C. Pedro Loza  2408  2022
#
# [150 rows x 4 columns]

# %%
# export data
# startEnd_df.to_csv('../../MiBici_Data/Tableau_Datasets/Question_4/popular_routes_count.csv', index=False, encoding='utf-8')

# %% [markdown]
# Find the most popular start/end stations separately

# %%
# Loop through each file, temporarily save as dataframe
popStat_df = pd.DataFrame()

for file in years_df:
    # obtain counts of start trip
    start_df = file.groupby(['Start_Name']).size().reset_index(name = "size").sort_values("size", ascending = False).reset_index(drop=True).head(25)
    end_df   = file.groupby(['End_Name']).size().reset_index(name = "size").sort_values("size", ascending = False).reset_index(drop=True).head(25)
    
    # Add Date to dataframe and turn into type datetime
    start_df['Date']      = pd.to_datetime(file['Start_Time'][0])
    start_df['Date']      = start_df['Date'].dt.strftime("%Y")
    start_df['Direction'] = 'Start'
    
    end_df['Date']      = start_df['Date']
    end_df['Direction'] = 'End'

    # Rename columns for concatenation
    
    start_df.rename({'Start_Name':'Station'}, axis='columns', inplace=True)
    end_df.rename({'End_Name':'Station' }, axis='columns', inplace=True)
  
    # concatenate to full dataframe
    popStat_df = pd.concat([popStat_df, start_df, end_df], axis=0)

# %%
popStat_df
# Out:
#                                  Station   size  Date Direction
# 0      Lopez Cotilla/ Marcos Castellanos  48794  2017     Start
# 1    C. Constancio Hernández/ Av. Juaréz  46553  2017     Start
# 2    C. Pedro Moreno / Calz. Federalismo  42026  2017     Start
# 3        Calz. Federalismo/ C. J. Angulo  37779  2017     Start
# 4           Av. La Paz / Av. Federalismo  36816  2017     Start
# ..                                   ...    ...   ...       ...
# 20           C. Jesús García/Av. Alcalde  25976  2022       End
# 21      C. Juan Manuel / C. Andrés Terán  25770  2022       End
# 22   C. J. Angulo/C José Clemente Orozco  25620  2022       End
# 23          C. Ramón Corona / Av. Juárez  25274  2022       End
# 24      C. Pedro Loza / Av. Manuel Acuña  24298  2022       End
#
# [300 rows x 4 columns]

# %%
# export data
# popStat_df.to_csv('../../MiBici_Data/Tableau_Datasets/Question_4/popular_stations_count.csv', index=False, encoding='utf-8')

# %% [markdown]
# ### Butterfly Chart

# %% [markdown]
# Number of trips starting and ending at each station is calculated for each year (also municipalities counts are calculated)

# %%
MiBici2022.groupby(['Start_Name']).size()
# Out:
# Start_Name
#   C. Donato Guerra /Av. La Paz          13217
#   C. Juan Manuel / C. Andrés Terán      27868
#   C. Mariano Bárcena / Maestros          9960
#   C. Relojeros/ C. Chamizal              2292
#  Av Lázaro Cárdenas / Av San Ignacio     4127
#                                         ...
#  Plaza de los Mariachis                  5778
#  Prol. Laureles / Av. J. Parres Aria     5477
#  Prol. Laureles / Av. Periférico G.      3795
#  Salvador Quevedo/López Portillo         8282
#  Ávila Camacho/ Lábaro Patrio            6512
# Length: 300, dtype: int64

# %%
MiBici2022.groupby(['End_Name']).size()
# Out:
# End_Name
#   C. Donato Guerra /Av. La Paz          13765
#   C. Juan Manuel / C. Andrés Terán      25770
#   C. Mariano Bárcena / Maestros         11437
#   C. Relojeros/ C. Chamizal              2184
#  Av Lázaro Cárdenas / Av San Ignacio     2919
#                                         ...
#  Plaza de los Mariachis                  7484
#  Prol. Laureles / Av. J. Parres Aria     5317
#  Prol. Laureles / Av. Periférico G.      4325
#  Salvador Quevedo/López Portillo         8657
#  Ávila Camacho/ Lábaro Patrio            7743
# Length: 300, dtype: int64

# %% [markdown]
# ### Parallel Chart

# %%
MiBici2022.groupby(['Start_Name', 'End_Name']).size().reset_index(name = "size").sort_values("size", ascending = False).reset_index(drop=True).head(25)
# Out:
#                               Start_Name  \
# 0    Av. J. Parres Arias / Prol. López C
# 1      Lopez Cotilla/ Marcos Castellanos
# 2    Av. Periférico G. Morín / Av. J. Pa
# 3    C. Constancio Hernández/ Av. Juaréz
# 4              Av. Alcalde / C. Hospital
# 5        Calz. Federalismo/ C. J. Angulo
# 6         C. Marsella / C. López Cotilla
# 7        C. Colonias  / C. López Cotilla
# 8      Av. Juárez / Av. 16 de Septiembre
# 9           Av. La Paz / Av. Federalismo
# 10           Av. Hidalgo / C. Pedro Loza
# 11       Av. Vallarta / Av. de Los Arcos
# 12     Lopez Cotilla/ Marcos Castellanos
# 13       Av. Vallarta / Av. de Los Arcos
# 14   C. Miguel Blanco / C. Penitenciaria
# 15            C. Degollado / Av. Hidalgo
# 16       C. Montenegro / Av. Chapultepec
# 17     Lopez Cotilla/ Marcos Castellanos
# 18   C. Pedro Moreno / Calz. Federalismo
# 19      Av. Juárez / Calz. Independencia
# 20     Lopez Cotilla/ Marcos Castellanos
# 21     C. Marcos Castellanos/ C. Morelos
# 22     Av. Aurelio Ortega / Av. Laureles
# 23   C. Duque de Rivas/ C. López Cotilla
# 24             Av. Alcalde / C. Hospital
#
#                                 End_Name  size
# 0    Av. Periférico G. Morín / Av. J. Pa  6466
# 1      Lopez Cotilla/ Marcos Castellanos  5447
# 2    Av. J. Parres Arias / Prol. López C  5223
# 3    C. Constancio Hernández/ Av. Juaréz  3825
# 4              Av. Alcalde / C. Hospital  3737
# 5        Calz. Federalismo/ C. J. Angulo  3683
# 6      Lopez Cotilla/ Marcos Castellanos  3656
# 7      Lopez Cotilla/ Marcos Castellanos  3566
# 8      Av. Juárez / Av. 16 de Septiembre  3405
# 9           Av. La Paz / Av. Federalismo  3375
# 10           Av. Hidalgo / C. Pedro Loza  3371
# 11       Av. Vallarta / Av. de Los Arcos  3286
# 12       C. Colonias  / C. López Cotilla  3154
# 13     Lopez Cotilla/ Marcos Castellanos  3133
# 14   C. Miguel Blanco / C. Penitenciaria  3098
# 15            C. Degollado / Av. Hidalgo  2949
# 16       C. Montenegro / Av. Chapultepec  2892
# 17                C. Libertad / C. Moscú  2867
# 18   C. Pedro Moreno / Calz. Federalismo  2681
# 19      Av. Juárez / Calz. Independencia  2597
# 20          Av. La Paz / Av. Federalismo  2566
# 21              C. Morelos / C. Progreso  2525
# 22       Av. Aurelio Ortega / C. Morelos  2487
# 23     Lopez Cotilla/ Marcos Castellanos  2481
# 24           Av. Hidalgo / C. Pedro Loza  2408

# %%
pd.DataFrame([years_df[i].loc[(years_df[i]['Start_Weekday'] == 'Saturday') | (years_df[i]['Start_Weekday'] == 'Sunday')].groupby('Start_Hour').size()   \
              for i in range(len(years)) 
             ], index=years).T

# %% [markdown]
# ### Google Maps Routes

# %% [markdown]
# #### Testing API

# %%
import requests   # access google directions API
import polyline   # convert polyine into coordinates

# %%
# this function creates the google.maps url needed to obtain the directions between any two points
def google_directions(s_lat, s_lng, e_lat, e_lng, avd, trnsprt_mode, API_k):
    
    # build url address for directions
    url = "https://maps.googleapis.com/maps/api/directions/json?"     \
          + "origin=" + s_lat + "%2C" + s_lng                         \
          + "&destination=" + e_lat + "%2C" + e_lng                   \
          + "&avoid=" + avd                                           \
          + "&mode=" + trnsprt_mode                                   \
          + "&key=" + API_k
    
    payload={}
    headers = {}
    
    # Request access to the google apis webpage.
    response = requests.request("GET", url, headers=headers, data=payload)
    return response

# %%
# Inputs for function above 

# Google API Key
from pathlib import Path
API_Key= Path('../../MiBici_Data/GDirections_API_Key.txt').read_text()

# avoid highways and find directions for a cyclist
avoid = 'highway'
transport_mode = 'bicycling'

# define the start and end locations in latlng
start_lat = '20.69406'
start_lng = '-103.34824'
end_lat   = '20.666378'
end_lng   = '-103.34882'

# %%
# Request access to the google apis webpage. 
response = google_directions(start_lat, start_lng, end_lat, end_lng, avoid, transport_mode, API_Key)

#<Response [200]> indicates that the request is successful.
response
# Out:
# <Response [200]>

# %%
# Obtain the polyline that contains all info about coordinates of directions
response.json()['routes'][0]['overview_polyline']['points']
# Out:
# 'yxh}BlfxuRo@@e@?OEIc@Qc@SQWQ_@Km@C]Dc@N]VWn@G\\AZ@n@N`@X^b@Rd@Jj@AVE`@QPM\\k@La@?IDEHGTGpCGbBGjO[~EK|@A@~@DnFPpGH|DpMLxPTxGH~OPpD@xFLVAt@I|BGjC@pCJ~CBzKL|KP~CDhI~ArCeLVoAz@qFXmB'

# %%
# Convert polyline into a list of tuple lat/lngs
locations = polyline.decode(response.json()['routes'][0]['overview_polyline']['points'])
locations
# Out:
# [(20.69405, -103.34839),
#  (20.69429, -103.3484),
#  (20.69448, -103.3484),
#  (20.69456, -103.34837),
#  (20.69461, -103.34819),
#  (20.6947, -103.34801),
#  (20.6948, -103.34792),
#  (20.69492, -103.34783),
#  (20.69508, -103.34777),
#  (20.69531, -103.34775),
#  (20.69546, -103.34778),
#  (20.69564, -103.34786),
#  (20.69579, -103.34798),
#  (20.69591, -103.34822),
#  (20.69595, -103.34837),
#  (20.69596, -103.34851),
#  (20.69595, -103.34875),
#  (20.69587, -103.34892),
#  (20.69574, -103.34908),
#  (20.69556, -103.34918),
#  (20.69537, -103.34924),
#  (20.69515, -103.34923),
#  (20.69503, -103.3492),
#  (20.69486, -103.34911),
#  (20.69477, -103.34904),
#  (20.69462, -103.34882),
#  (20.69455, -103.34865),
#  (20.69455, -103.3486),
#  (20.69452, -103.34857),
#  (20.69447, -103.34853),
#  (20.69436, -103.34849),
#  (20.69363, -103.34845),
#  (20.69313, -103.34841),
#  (20.69051, -103.34827),
#  (20.68939, -103.34821),
#  (20.68908, -103.3482),
#  (20.68907, -103.34852),
#  (20.68904, -103.34972),
#  (20.68895, -103.35109),
#  (20.6889, -103.35204),
#  (20.68657, -103.35211),
#  (20.68372, -103.35222),
#  (20.68231, -103.35227),
#  (20.67959, -103.35236),
#  (20.6787, -103.35237),
#  (20.67745, -103.35244),
#  (20.67733, -103.35243),
#  (20.67706, -103.35238),
#  (20.67643, -103.35234),
#  (20.67573, -103.35235),
#  (20.675, -103.35241),
#  (20.6742, -103.35243),
#  (20.67214, -103.3525),
#  (20.67007, -103.35259),
#  (20.66927, -103.35262),
#  (20.66762, -103.3531),
#  (20.66688, -103.35099),
#  (20.66676, -103.35059),
#  (20.66646, -103.34938),
#  (20.66633, -103.34883)]

# %%
# Create map of route
m = folium.Map()
folium.PolyLine(locations).add_to(m)

# Changes for within range
#sw = [min(list(map(list, zip(*locations)))[0]), min(list(map(list, zip(*locations)))[1])]
#ne = [max(list(map(list, zip(*locations)))[0]), max(list(map(list, zip(*locations)))[1])]

sw = [response.json()['routes'][0]['bounds']['southwest']['lat'], response.json()['routes'][0]['bounds']['southwest']['lng']]
ne = [response.json()['routes'][0]['bounds']['northeast']['lat'], response.json()['routes'][0]['bounds']['northeast']['lng']]

m.fit_bounds([sw, ne])

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_ab6ce1ad5e8b46b5a8a64bce3aa48d5b%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_ab6ce1ad5e8b46b5a8a64bce3aa48d5b%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_ab6ce1ad5e8b46b5a8a64bce3aa48d5b%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_ab6ce1ad5e8b46b5a8a64bce3aa48d5b%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B0%2C%200%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20crs%3A%2 ...

# %%
response.json()['routes'][0].keys()
start_lat = '20.69406'
start_lng = '-103.34824'
end_lat   = '20.666378'
end_lng   = '-103.34882'
# Out:
# dict_keys(['bounds', 'copyrights', 'legs', 'overview_polyline', 'summary', 'warnings', 'waypoint_order'])

# %%
response.json()['routes'][0]['legs'][0]['duration']['text']
# Out:
# '16 mins'

# %% [markdown]
# #### Most Common Routes

# %%
pop_stations_df = \
pd.concat([years_df[i].groupby(["Start_Name","End_Name"]).size().reset_index(name = "Number of Trips").sort_values("Number of Trips", ascending = False).reset_index(drop=True).head(15)   \
              for i in range(len(years)) 
          ], axis=0, keys=years)

# %%
pop_stations_df
# Out:
#                                    Start_Name  \
# 2017 0             C. Juan Álvarez / C. Belén
#      1             C. Juan Álvarez / C. Belén
#      2    C. Miguel Blanco / C. Penitenciaria
#      3      Lopez Cotilla/ Marcos Castellanos
#      4         C. Marsella / C. López Cotilla
# ...                                       ...
# 2022 10           Av. Hidalgo / C. Pedro Loza
#      11       Av. Vallarta / Av. de Los Arcos
#      12     Lopez Cotilla/ Marcos Castellanos
#      13       Av. Vallarta / Av. de Los Arcos
#      14   C. Miguel Blanco / C. Penitenciaria
#
#                                      End_Name  Number of Trips
# 2017 0             C. Juan Álvarez / C. Belén             2953
#      1    C. Monte Cáucaso / C. Sierra Nevada             2745
#      2    C. Miguel Blanco / C. Penitenciaria             2477
#      3      Lopez Cotilla/ Marcos Castellanos             2414
#      4      Lopez Cotilla/ Marcos Castellanos             2328
# ...                                       ...              ...
# 2022 10           Av. Hidalgo / C. Pedro Loza             3371
#      11       Av. Vallarta / Av. de Los Arcos             3286
#      12       C. Colonias  / C. López Cotilla             3154
#      13     Lopez Cotilla/ Marcos Castellanos             3133
#      14   C. Miguel Blanco / C. Penitenciaria             3098
#
# [90 rows x 3 columns]

# %%
# turn hierarchical indices into column for year
pop_stations_df.reset_index(inplace=True)

# delete index column of [0:14] per year
pop_stations_df.drop('level_1', axis=1, inplace=True)

# rename 'level_0' column to year
pop_stations_df.rename(columns={'level_0': 'Year'}, inplace=True)

# %%
pop_stations_df
# Out:
#     Year                            Start_Name  \
# 0   2017            C. Juan Álvarez / C. Belén
# 1   2017            C. Juan Álvarez / C. Belén
# 2   2017   C. Miguel Blanco / C. Penitenciaria
# 3   2017     Lopez Cotilla/ Marcos Castellanos
# 4   2017        C. Marsella / C. López Cotilla
# ..   ...                                   ...
# 85  2022           Av. Hidalgo / C. Pedro Loza
# 86  2022       Av. Vallarta / Av. de Los Arcos
# 87  2022     Lopez Cotilla/ Marcos Castellanos
# 88  2022       Av. Vallarta / Av. de Los Arcos
# 89  2022   C. Miguel Blanco / C. Penitenciaria
#
#                                 End_Name  Number of Trips
# 0             C. Juan Álvarez / C. Belén             2953
# 1    C. Monte Cáucaso / C. Sierra Nevada             2745
# 2    C. Miguel Blanco / C. Penitenciaria             2477
# 3      Lopez Cotilla/ Marcos Castellanos             2414
# 4      Lopez Cotilla/ Marcos Castellanos             2328
# ..                                   ...              ...
# 85           Av. Hidalgo / C. Pedro Loza             3371
# 86       Av. Vallarta / Av. de Los Arcos             3286
# 87       C. Colonias  / C. López Cotilla             3154
# 88     Lopez Cotilla/ Marcos Castellanos             3133
# 89   C. Miguel Blanco / C. Penitenciaria             3098
#
# [90 rows x 4 columns]

# %% [markdown]
# Use match index to obtain additional info for each start/end station

# %%
# import station dataframe
all_stations_new_df = pd.read_csv('../../MiBici_Data/nomenclatura_2022_10_updated.csv', encoding='utf-8')

# %%
# Match index for STARTING Station
pop_stations_df = pop_stations_df.merge(all_stations_new_df, how='left', left_on='Start_Name', right_on='name')

# Rename columns for start station
pop_stations_df.rename(columns=({'latitude'      : 'Start_Latitude',  
                                 'longitude'     : 'Start_Longitude',
                                 'status'        : 'Start_Status',
                                 'geometry'      : 'Start_Geometry',
                                 'address'       : 'Start_Address',
                                 'city'          : 'Start_City',
                                 'neighbourhood' : 'Start_Neighborhood'}
                               ), inplace=True)

pop_stations_df.drop(['id', 'name', 'obcn', 'location'], axis=1, inplace=True)

# %%
pop_stations_df
# Out:
#     Year                            Start_Name  \
# 0   2017            C. Juan Álvarez / C. Belén
# 1   2017            C. Juan Álvarez / C. Belén
# 2   2017   C. Miguel Blanco / C. Penitenciaria
# 3   2017     Lopez Cotilla/ Marcos Castellanos
# 4   2017        C. Marsella / C. López Cotilla
# ..   ...                                   ...
# 85  2022           Av. Hidalgo / C. Pedro Loza
# 86  2022       Av. Vallarta / Av. de Los Arcos
# 87  2022     Lopez Cotilla/ Marcos Castellanos
# 88  2022       Av. Vallarta / Av. de Los Arcos
# 89  2022   C. Miguel Blanco / C. Penitenciaria
#
#                                 End_Name  Number of Trips  Start_Latitude  \
# 0             C. Juan Álvarez / C. Belén             2953       20.684650
# 1    C. Monte Cáucaso / C. Sierra Nevada             2745       20.684650
# 2    C. Miguel Blanco / C. Penitenciaria             2477       20.672231
# 3      Lopez Cotilla/ Marcos Castellanos             2414       20.674087
# 4      Lopez Cotilla/ Marcos Castellanos             2328       20.673321
# ..                                   ...              ...             ...
# 85           Av. Hidalgo / C. Pedro Loza             3371       20.677419
# 86       Av. Vallarta / Av. de Los Arcos             3286       20.674380
# 87       C. Colonias  / C. López Cotilla             3154       20.674087
# 88     Lopez Cotilla/ Marcos Castellanos             3133       20.674380
# 89   C. Miguel Blanco / C. Penitenciaria             3098       20.672231
#
#     Start_Longitude Start_Status           Start_Geometry  \
# 0       -103.345260   IN_SERVICE      20.68465,-103.34526
# 1       -103.345260   IN_SERVICE      20.68465,-103.34526
# 2       -103.355508   IN_SERVICE    20.672231,-103.355508
# 3       -103.356320   IN_SERVICE  20.6740865,-103.3563196
# 4       -103.370571   IN_SERVICE    20.673321,-103.370571
# ..              ...          ...                      ...
# 85      -103.347983   IN_SERVICE    20.677419,-103.347983
# 86      -103.384880   IN_SERVICE      20.67438,-103.38488
# 87      -103.356320   IN_SERVICE  20.6740865,-103.3563196
# 88      -103.384880   IN_SERVICE      20.67438,-103.38488
# 89      -103.355508   IN_SERVICE    20.672231,-103.355508
#
#                                         Start_Address   Start_City  \
# 0   498, Calle Belén, 44280, Calle Belén, Guadalaj...  Guadalajara
# 1   498, Calle Belén, 44280, Calle Belén, Guadalaj...  Guadalajara
# 2   MiBici, Miguel Blanco, 44170, Miguel Blanco, G...  Guadalajara
# 3   771, Calle López Cotilla, 44100, Calle López C...  Guadalajara
# 4   MiBici, Calle Marsella, 44140, Calle Marsella,...  Guadalajara
# ..                                                ...          ...
# 85  MiBici, Avenida Hidalgo, 44100, Avenida Hidalg...  Guadalajara
# 86  Los Arcos, Avenida Ignacio L. Vallarta, 44130,...  Guadalajara
# 87  771, Calle López Cotilla, 44100, Calle López C...  Guadalajara
# 88  Los Arcos, Avenida Ignacio L. Vallarta, 44130,...  Guadalajara
# 89  MiBici, Miguel Blanco, 44170, Miguel Blanco, G...  Guadalajara
#
#      Start_Neighborhood
# 0   Centro Barranquitas
# 1   Centro Barranquitas
# 2             Americana
# 3    Las Nueve Esquinas
# 4                Obrera
# ..                  ...
# 85   Guadalajara Centro
# 86       Arcos Vallarta
# 87   Las Nueve Esquinas
# 88       Arcos Vallarta
# 89            Americana
#
# [90 rows x 11 columns]

# %%
# Match index for ENDING Stations
pop_stations_df = pop_stations_df.merge(all_stations_new_df, how='left', left_on='End_Name', right_on='name')

# Rename columns for start station
pop_stations_df.rename(columns=({'latitude'      : 'End_Latitude',  
                                 'longitude'     : 'End_Longitude',
                                 'status'        : 'End_Status',
                                 'geometry'      : 'End_Geometry',
                                 'address'       : 'End_Address',
                                 'city'          : 'End_City',
                                 'neighbourhood' : 'End_Neighborhood'}
                               ), inplace=True)

pop_stations_df.drop(['id', 'name', 'obcn', 'location'], axis=1, inplace=True)

# %%
pop_stations_df
# Out:
#     Year                            Start_Name  \
# 0   2017            C. Juan Álvarez / C. Belén
# 1   2017            C. Juan Álvarez / C. Belén
# 2   2017   C. Miguel Blanco / C. Penitenciaria
# 3   2017     Lopez Cotilla/ Marcos Castellanos
# 4   2017        C. Marsella / C. López Cotilla
# ..   ...                                   ...
# 85  2022           Av. Hidalgo / C. Pedro Loza
# 86  2022       Av. Vallarta / Av. de Los Arcos
# 87  2022     Lopez Cotilla/ Marcos Castellanos
# 88  2022       Av. Vallarta / Av. de Los Arcos
# 89  2022   C. Miguel Blanco / C. Penitenciaria
#
#                                 End_Name  Number of Trips  Start_Latitude  \
# 0             C. Juan Álvarez / C. Belén             2953       20.684650
# 1    C. Monte Cáucaso / C. Sierra Nevada             2745       20.684650
# 2    C. Miguel Blanco / C. Penitenciaria             2477       20.672231
# 3      Lopez Cotilla/ Marcos Castellanos             2414       20.674087
# 4      Lopez Cotilla/ Marcos Castellanos             2328       20.673321
# ..                                   ...              ...             ...
# 85           Av. Hidalgo / C. Pedro Loza             3371       20.677419
# 86       Av. Vallarta / Av. de Los Arcos             3286       20.674380
# 87       C. Colonias  / C. López Cotilla             3154       20.674087
# 88     Lopez Cotilla/ Marcos Castellanos             3133       20.674380
# 89   C. Miguel Blanco / C. Penitenciaria             3098       20.672231
#
#     Start_Longitude Start_Status           Start_Geometry  \
# 0       -103.345260   IN_SERVICE      20.68465,-103.34526
# 1       -103.345260   IN_SERVICE      20.68465,-103.34526
# 2       -103.355508   IN_SERVICE    20.672231,-103.355508
# 3       -103.356320   IN_SERVICE  20.6740865,-103.3563196
# 4       -103.370571   IN_SERVICE    20.673321,-103.370571
# ..              ...          ...                      ...
# 85      -103.347983   IN_SERVICE    20.677419,-103.347983
# 86      -103.384880   IN_SERVICE      20.67438,-103.38488
# 87      -103.356320   IN_SERVICE  20.6740865,-103.3563196
# 88      -103.384880   IN_SERVICE      20.67438,-103.38488
# 89      -103.355508   IN_SERVICE    20.672231,-103.355508
#
#                                         Start_Address   Start_City  \
# 0   498, Calle Belén, 44280, Calle Belén, Guadalaj...  Guadalajara
# 1   498, Calle Belén, 44280, Calle Belén, Guadalaj...  Guadalajara
# 2   MiBici, Miguel Blanco, 44170, Miguel Blanco, G...  Guadalajara
# 3   771, Calle López Cotilla, 44100, Calle López C...  Guadalajara
# 4   MiBici, Calle Marsella, 44140, Calle Marsella,...  Guadalajara
# ..                                                ...          ...
# 85  MiBici, Avenida Hidalgo, 44100, Avenida Hidalg...  Guadalajara
# 86  Los Arcos, Avenida Ignacio L. Vallarta, 44130,...  Guadalajara
# 87  771, Calle López Cotilla, 44100, Calle López C...  Guadalajara
# 88  Los Arcos, Avenida Ignacio L. Vallarta, 44130,...  Guadalajara
# 89  MiBici, Miguel Blanco, 44170, Miguel Blanco, G...  Guadalajara
#
#      Start_Neighborhood  End_Latitude  End_Longitude  End_Status  \
# 0   Centro Barranquitas     20.684650    -103.345260  IN_SERVICE
# 1   Centro Barranquitas     20.687950    -103.333430  IN_SERVICE
# 2             Americana     20.672231    -103.355508  IN_SERVICE
# 3    Las Nueve Esquinas     20.674087    -103.356320  IN_SERVICE
# 4                Obrera     20.674087    -103.356320  IN_SERVICE
# ..                  ...           ...            ...         ...
# 85   Guadalajara Centro     20.677419    -103.347983  IN_SERVICE
# 86       Arcos Vallarta     20.674380    -103.384880  IN_SERVICE
# 87   Las Nueve Esquinas     20.674132    -103.366139  IN_SERVICE
# 88       Arcos Vallarta     20.674087    -103.356320  IN_SERVICE
# 89            Americana     20.672231    -103.355508  IN_SERVICE
#
#                End_Geometry  \
# 0       20.68465,-103.34526
# 1       20.68795,-103.33343
# 2     20.672231,-103.355508
# 3   20.6740865,-103.3563196
# 4   20.6740865,-103.3563196
# ..                      ...
# 85    20.677419,-103.347983
# 86      20.67438,-103.38488
# 87    20.674132,-103.366139
# 88  20.6740865,-103.3563196
# 89    20.672231,-103.355508
#
#                                           End_Address     End_City  \
# 0   498, Calle Belén, 44280, Calle Belén, Guadalaj...  Guadalajara
# 1   909, Calle Sierra Nevada, 44340, Calle Sierra ...  Guadalajara
# 2   MiBici, Miguel Blanco, 44170, Miguel Blanco, G...  Guadalajara
# 3   771, Calle López Cotilla, 44100, Calle López C...  Guadalajara
# 4   771, Calle López Cotilla, 44100, Calle López C...  Guadalajara
# ..                                                ...          ...
# 85  MiBici, Avenida Hidalgo, 44100, Avenida Hidalg...  Guadalajara
# 86  Los Arcos, Avenida Ignacio L. Vallarta, 44130,...  Guadalajara
# 87  129, Calle Colonias, 44140, Calle Colonias, Gu...  Guadalajara
# 88  771, Calle López Cotilla, 44100, Calle López C...  Guadalajara
# 89  MiBici, Miguel Blanco, 44170, Miguel Blanco, G...  Guadalajara
#
#          End_Neighborhood
# 0     Centro Barranquitas
# 1   Independencia Oriente
# 2               Americana
# 3      Las Nueve Esquinas
# 4      Las Nueve Esquinas
# ..                    ...
# 85     Guadalajara Centro
# 86         Arcos Vallarta
# 87              Americana
# 88     Las Nueve Esquinas
# 89              Americana
#
# [90 rows x 18 columns]

# %%
# export data
# pop_stations_df.to_csv('../../MiBici_Data/Tableau_Datasets/Question_4/popular_routes_count.csv', index=False, encoding = 'utf-8')

# %% [markdown]
# #### Route for Popular Trips

# %%
list = []

# loop through each row, enter start/end lat/lng info into google maps to obtain bicycle route.
for i in pop_stations_df.index:
    
    # Request access to the google apis webpage. Enter lat/lng data for each route in df 
    response = google_directions(pop_stations_df['Start_Latitude'][i].astype('str'), 
                                 pop_stations_df['Start_Longitude'][i].astype('str'), 
                                 pop_stations_df['End_Latitude'][i].astype('str'), 
                                 pop_stations_df['End_Longitude'][i].astype('str'), 
                                 avoid, transport_mode, API_Key)
    
    # Obtain polyline of route and convert it into a list of tuple lat/lngs
    # append to list
    list.append(polyline.decode(response.json()['routes'][0]['overview_polyline']['points']))

# %%
pop_stations_df['Route'] = pd.Series(list)

# %%
pop_stations_df
# Out:
#     Year                            Start_Name  \
# 0   2017            C. Juan Álvarez / C. Belén
# 1   2017            C. Juan Álvarez / C. Belén
# 2   2017   C. Miguel Blanco / C. Penitenciaria
# 3   2017     Lopez Cotilla/ Marcos Castellanos
# 4   2017        C. Marsella / C. López Cotilla
# ..   ...                                   ...
# 85  2022           Av. Hidalgo / C. Pedro Loza
# 86  2022       Av. Vallarta / Av. de Los Arcos
# 87  2022     Lopez Cotilla/ Marcos Castellanos
# 88  2022       Av. Vallarta / Av. de Los Arcos
# 89  2022   C. Miguel Blanco / C. Penitenciaria
#
#                                 End_Name  Number of Trips  Start_Latitude  \
# 0             C. Juan Álvarez / C. Belén             2953       20.684650
# 1    C. Monte Cáucaso / C. Sierra Nevada             2745       20.684650
# 2    C. Miguel Blanco / C. Penitenciaria             2477       20.672231
# 3      Lopez Cotilla/ Marcos Castellanos             2414       20.674087
# 4      Lopez Cotilla/ Marcos Castellanos             2328       20.673321
# ..                                   ...              ...             ...
# 85           Av. Hidalgo / C. Pedro Loza             3371       20.677419
# 86       Av. Vallarta / Av. de Los Arcos             3286       20.674380
# 87       C. Colonias  / C. López Cotilla             3154       20.674087
# 88     Lopez Cotilla/ Marcos Castellanos             3133       20.674380
# 89   C. Miguel Blanco / C. Penitenciaria             3098       20.672231
#
#     Start_Longitude Start_Status           Start_Geometry  \
# 0       -103.345260   IN_SERVICE      20.68465,-103.34526
# 1       -103.345260   IN_SERVICE      20.68465,-103.34526
# 2       -103.355508   IN_SERVICE    20.672231,-103.355508
# 3       -103.356320   IN_SERVICE  20.6740865,-103.3563196
# 4       -103.370571   IN_SERVICE    20.673321,-103.370571
# ..              ...          ...                      ...
# 85      -103.347983   IN_SERVICE    20.677419,-103.347983
# 86      -103.384880   IN_SERVICE      20.67438,-103.38488
# 87      -103.356320   IN_SERVICE  20.6740865,-103.3563196
# 88      -103.384880   IN_SERVICE      20.67438,-103.38488
# 89      -103.355508   IN_SERVICE    20.672231,-103.355508
#
#                                         Start_Address   Start_City  \
# 0   498, Calle Belén, 44280, Calle Belén, Guadalaj...  Guadalajara
# 1   498, Calle Belén, 44280, Calle Belén, Guadalaj...  Guadalajara
# 2   MiBici, Miguel Blanco, 44170, Miguel Blanco, G...  Guadalajara
# 3   771, Calle López Cotilla, 44100, Calle López C...  Guadalajara
# 4   MiBici, Calle Marsella, 44140, Calle Marsella,...  Guadalajara
# ..                                                ...          ...
# 85  MiBici, Avenida Hidalgo, 44100, Avenida Hidalg...  Guadalajara
# 86  Los Arcos, Avenida Ignacio L. Vallarta, 44130,...  Guadalajara
# 87  771, Calle López Cotilla, 44100, Calle López C...  Guadalajara
# 88  Los Arcos, Avenida Ignacio L. Vallarta, 44130,...  Guadalajara
# 89  MiBici, Miguel Blanco, 44170, Miguel Blanco, G...  Guadalajara
#
#      Start_Neighborhood  End_Latitude  End_Longitude  End_Status  \
# 0   Centro Barranquitas     20.684650    -103.345260  IN_SERVICE
# 1   Centro Barranquitas     20.687950    -103.333430  IN_SERVICE
# 2             Americana     20.672231    -103.355508  IN_SERVICE
# 3    Las Nueve Esquinas     20.674087    -103.356320  IN_SERVICE
# 4                Obrera     20.674087    -103.356320  IN_SERVICE
# ..                  ...           ...            ...         ...
# 85   Guadalajara Centro     20.677419    -103.347983  IN_SERVICE
# 86       Arcos Vallarta     20.674380    -103.384880  IN_SERVICE
# 87   Las Nueve Esquinas     20.674132    -103.366139  IN_SERVICE
# 88       Arcos Vallarta     20.674087    -103.356320  IN_SERVICE
# 89            Americana     20.672231    -103.355508  IN_SERVICE
#
#                End_Geometry  \
# 0       20.68465,-103.34526
# 1       20.68795,-103.33343
# 2     20.672231,-103.355508
# 3   20.6740865,-103.3563196
# 4   20.6740865,-103.3563196
# ..                      ...
# 85    20.677419,-103.347983
# 86      20.67438,-103.38488
# 87    20.674132,-103.366139
# 88  20.6740865,-103.3563196
# 89    20.672231,-103.355508
#
#                                           End_Address     End_City  \
# 0   498, Calle Belén, 44280, Calle Belén, Guadalaj...  Guadalajara
# 1   909, Calle Sierra Nevada, 44340, Calle Sierra ...  Guadalajara
# 2   MiBici, Miguel Blanco, 44170, Miguel Blanco, G...  Guadalajara
# 3   771, Calle López Cotilla, 44100, Calle López C...  Guadalajara
# 4   771, Calle López Cotilla, 44100, Calle López C...  Guadalajara
# ..                                                ...          ...
# 85  MiBici, Avenida Hidalgo, 44100, Avenida Hidalg...  Guadalajara
# 86  Los Arcos, Avenida Ignacio L. Vallarta, 44130,...  Guadalajara
# 87  129, Calle Colonias, 44140, Calle Colonias, Gu...  Guadalajara
# 88  771, Calle López Cotilla, 44100, Calle López C...  Guadalajara
# 89  MiBici, Miguel Blanco, 44170, Miguel Blanco, G...  Guadalajara
#
#          End_Neighborhood                                              Route
# 0     Centro Barranquitas                           [(20.68465, -103.34526)]
# 1   Independencia Oriente  [(20.68465, -103.34526), (20.68464, -103.34544...
# 2               Americana                            [(20.6722, -103.35551)]
# 3      Las Nueve Esquinas                           [(20.67407, -103.35632)]
# 4      Las Nueve Esquinas  [(20.67332, -103.37055), (20.67368, -103.37056...
# ..                    ...                                                ...
# 85     Guadalajara Centro                            [(20.6774, -103.34798)]
# 86         Arcos Vallarta                           [(20.67446, -103.38488)]
# 87              Americana  [(20.67407, -103.35632), (20.67412, -103.35548...
# 88     Las Nueve Esquinas  [(20.67446, -103.38488), (20.67446, -103.38533...
# 89              Americana                            [(20.6722, -103.35551)]
#
# [90 rows x 19 columns]

# %% [markdown]
# Format data for Tableau

# %% [markdown]
# A path ID for every unique path.
# Order of Points column: index order of lat/lng per path
# Latitude and longitude coordinates for every location
# Route name
# number of trips

# %%
temp_df       = pd.DataFrame()
tab_routes_df = pd.DataFrame()

# loop through each row, for each route, create appropriate dataframe format and append to 'tab_routes_df'
for i in pop_stations_df.index:
    temp_df = pd.DataFrame(pop_stations_df.Route[i], columns = ['Latitude', 'Longitude'])
    temp_df['Order of Points'] = temp_df.index + 1
    temp_df['Path ID']         = pd.DataFrame([i + 1]*len(temp_df))
    temp_df['Line']            = pd.DataFrame([i + 1]*len(temp_df))
    temp_df['Start Name']      = pd.DataFrame([pop_stations_df['Start_Name'][i]]*len(temp_df))
    temp_df['End Name']        = pd.DataFrame([pop_stations_df['End_Name'][i]]*len(temp_df))
    temp_df['Number of Trips'] = pd.DataFrame([pop_stations_df['Number of Trips'][i]]*len(temp_df))
    temp_df['Year']            = pd.DataFrame([pop_stations_df['Year'][i]]*len(temp_df))
    
    tab_routes_df = pd.concat([tab_routes_df, temp_df], axis=0)
    
    temp_df = pd.DataFrame()

# %%
tab_routes_df
# Out:
#     Latitude  Longitude  Order of Points  Path ID  Line  \
# 0   20.68465 -103.34526                1        1     1
# 0   20.68465 -103.34526                1        2     2
# 1   20.68464 -103.34544                2        2     2
# 2   20.68542 -103.34551                3        2     2
# 3   20.68557 -103.34552                4        2     2
# ..       ...        ...              ...      ...   ...
# 25  20.67388 -103.36395               26       89    89
# 26  20.67401 -103.35905               27       89    89
# 27  20.67405 -103.35749               28       89    89
# 28  20.67407 -103.35632               29       89    89
# 0   20.67220 -103.35551                1       90    90
#
#                               Start Name  \
# 0             C. Juan Álvarez / C. Belén
# 0             C. Juan Álvarez / C. Belén
# 1             C. Juan Álvarez / C. Belén
# 2             C. Juan Álvarez / C. Belén
# 3             C. Juan Álvarez / C. Belén
# ..                                   ...
# 25       Av. Vallarta / Av. de Los Arcos
# 26       Av. Vallarta / Av. de Los Arcos
# 27       Av. Vallarta / Av. de Los Arcos
# 28       Av. Vallarta / Av. de Los Arcos
# 0    C. Miguel Blanco / C. Penitenciaria
#
#                                 End Name  Number of Trips  Year
# 0             C. Juan Álvarez / C. Belén             2953  2017
# 0    C. Monte Cáucaso / C. Sierra Nevada             2745  2017
# 1    C. Monte Cáucaso / C. Sierra Nevada             2745  2017
# 2    C. Monte Cáucaso / C. Sierra Nevada             2745  2017
# 3    C. Monte Cáucaso / C. Sierra Nevada             2745  2017
# ..                                   ...              ...   ...
# 25     Lopez Cotilla/ Marcos Castellanos             3133  2022
# 26     Lopez Cotilla/ Marcos Castellanos             3133  2022
# 27     Lopez Cotilla/ Marcos Castellanos             3133  2022
# 28     Lopez Cotilla/ Marcos Castellanos             3133  2022
# 0    C. Miguel Blanco / C. Penitenciaria             3098  2022
#
# [1068 rows x 9 columns]

# %%
# export data
# tab_routes_df.to_csv('../../MiBici_Data/Tableau_Datasets/Question_4/map_routes_count.csv', index=False, encoding = 'utf-8')

# %%
MiBici2022.groupby(['Start_Name', 'End_Name']).size().reset_index(name = "size").sort_values("size", ascending = False).reset_index(drop=True)
# Out:
#                                  Start_Name  \
# 0       Av. J. Parres Arias / Prol. López C
# 1       Av. Periférico G. Morín / Av. J. Pa
# 2            C. Marsella / C. López Cotilla
# 3           C. Colonias  / C. López Cotilla
# 4         Lopez Cotilla/ Marcos Castellanos
# ...                                     ...
# 54793   C. Niño Obrero /C José María Robles
# 54794   C. Niño Obrero /C José María Robles
# 54795   C. Niño Obrero /C José María Robles
# 54796   C. Niño Obrero /C José María Robles
# 54797            C. Maestranza / Av. Juárez
#
#                                    End_Name  size
# 0       Av. Periférico G. Morín / Av. J. Pa  6440
# 1       Av. J. Parres Arias / Prol. López C  5203
# 2         Lopez Cotilla/ Marcos Castellanos  3646
# 3         Lopez Cotilla/ Marcos Castellanos  3560
# 4           C. Colonias  / C. López Cotilla  3143
# ...                                     ...   ...
# 54793        C. Nicolás Romero / C. Reforma     1
# 54794    C. Ocampo / C. Prisciliano Sánchez     1
# 54795          C. Ramón Corona / Av. Juárez     1
# 54796   C. Ruíz de Alarcón/C. Efraín G Luna     1
# 54797   Av. M. Ávila Camacho / C. San Jorge     1
#
# [54798 rows x 3 columns]

# %%
MiBici2021.groupby(['Start_Name', 'End_Name']).size().reset_index(name = "size").sort_values("size", ascending = False).reset_index(drop=True)
# Out:
#                                  Start_Name  \
# 0       C. C. Orozco/C. Gral. Eulogio Parra
# 1            C. Marsella / C. López Cotilla
# 2       Av. J. Parres Arias / Prol. López C
# 3           C. Colonias  / C. López Cotilla
# 4       C. Miguel Blanco / C. Penitenciaria
# ...                                     ...
# 53427     Av. Juárez / Av. 16 de Septiembre
# 53428           C. D. Rivera / C. Filósofos
# 53429    C. Juan de Zumárraga / Av. Tepeyac
# 53430   Blvrd. García Barragán/ C. Rio Zapo
# 53431           Av. Guadalupe / C. Boturini
#
#                                    End_Name  size
# 0       C. C. Orozco/C. Gral. Eulogio Parra  3280
# 1         Lopez Cotilla/ Marcos Castellanos  3227
# 2       Av. Periférico G. Morín / Av. J. Pa  2994
# 3         Lopez Cotilla/ Marcos Castellanos  2770
# 4       C. Miguel Blanco / C. Penitenciaria  2720
# ...                                     ...   ...
# 53427    Av. Laureles / Blvrd. Panamericano     1
# 53428          Calz. Indep. /C. Juan Manuel     1
# 53429   Av Manuel Acuña/C. Pablo Villaseñor     1
# 53430   C. Guadalupe Zuno / Av. Chapultepec     1
# 53431    C.Silverio Garcia/Blvrd. García Ba     1
#
# [53432 rows x 3 columns]

# %%
MiBici2020.groupby(['Start_Name', 'End_Name']).size().reset_index(name = "size").sort_values("size", ascending = False).reset_index(drop=True)
# Out:
#                                  Start_Name  \
# 0       C. Miguel Blanco / C. Penitenciaria
# 1                  C. Hospital / C. Alameda
# 2           Av. Vallarta / Av. de Los Arcos
# 3           C. Colonias  / C. López Cotilla
# 4               Av. Hidalgo / C. Pedro Loza
# ...                                     ...
# 47023   C. Fco Rojas González /C. Garibaldi
# 47024   C. Fco Rojas González /C. Garibaldi
# 47025   C. Fco Rojas González /C. Garibaldi
# 47026   C. Suiza / Av. Enrique Díaz de león
# 47027   C. J. Ruíz de Alarcón / Av Vallarta
#
#                                    End_Name  size
# 0       C. Miguel Blanco / C. Penitenciaria  3356
# 1                  C. Hospital / C. Alameda  3195
# 2         Lopez Cotilla/ Marcos Castellanos  3065
# 3         Lopez Cotilla/ Marcos Castellanos  3054
# 4                 Av. Alcalde / C. Hospital  2858
# ...                                     ...   ...
# 47023    C. Ayuntamiento/C. A. R. Plasencia     1
# 47024         C. Capuchinas / Av. Las Rosas     1
# 47025      C. Firmamento / Av. Niños Héroes     1
# 47026     Calz Lázaro Cárdenas / Av San Fco     1
# 47027     Av. Aurelio Ortega / Av. Laureles     1
#
# [47028 rows x 3 columns]

# %%
MiBici2019.groupby(['Start_Name', 'End_Name']).size().reset_index(name = "size").sort_values("size", ascending = False).reset_index(drop=True)
# Out:
#                                 Start_Name  \
# 0          Av. Vallarta / Av. de Los Arcos
# 1          C. Colonias  / C. López Cotilla
# 2           C. Marsella / C. López Cotilla
# 3              Av. Hidalgo / C. Pedro Loza
# 4                Av. Alcalde / C. Hospital
# ...                                    ...
# 50101              C. Progreso / C. Juárez
# 50102              C. Progreso / C. Juárez
# 50103    C. Tonatiuh / Av. Netzahualcóyotl
# 50104           C. Chamizal / Av. Rio Nilo
# 50105   C.Silverio Garcia/Blvrd. García Ba
#
#                                    End_Name  size
# 0         Lopez Cotilla/ Marcos Castellanos  8667
# 1         Lopez Cotilla/ Marcos Castellanos  6712
# 2         Lopez Cotilla/ Marcos Castellanos  5194
# 3                 Av. Alcalde / C. Hospital  4565
# 4               Av. Hidalgo / C. Pedro Loza  4366
# ...                                     ...   ...
# 50101        C. Esmeralda / C. Manuel Acuña     1
# 50102   C. General Coronado / C.Juan Manuel     1
# 50103            C. Juan Álvarez / C. Belén     1
# 50104   C. Guadalupe Zuno / Av. Chapultepec     1
# 50105   J. Clemente Orozco /C. Jesús García     1
#
# [50106 rows x 3 columns]

# %%
MiBici2018.groupby(['Start_Name', 'End_Name']).size().reset_index(name = "size").sort_values("size", ascending = False).reset_index(drop=True)
# Out:
#                                  Start_Name  \
# 0           Av. Vallarta / Av. de Los Arcos
# 1           C. Colonias  / C. López Cotilla
# 2            C. Marsella / C. López Cotilla
# 3           C. Montenegro / Av. Chapultepec
# 4         Lopez Cotilla/ Marcos Castellanos
# ...                                     ...
# 43244    C. Juan de Zumárraga / Av. Tepeyac
# 43245         C. Donato Guerra / C. Obregón
# 43246         C. Donato Guerra / C. Obregón
# 43247    C. Juan de Zumárraga / Av. Tepeyac
# 43248   Av. M. Ávila Camacho / C. San Jorge
#
#                                    End_Name  size
# 0         Lopez Cotilla/ Marcos Castellanos  6152
# 1         Lopez Cotilla/ Marcos Castellanos  5343
# 2         Lopez Cotilla/ Marcos Castellanos  4279
# 3           C. Montenegro / Av. Chapultepec  4041
# 4           C. Colonias  / C. López Cotilla  3967
# ...                                     ...   ...
# 43244     C. General Coronado / Av. Hidalgo     1
# 43245   C. Montes Pirineos/Salvador Quevedo     1
# 43246      C. Pavo / C. Prisciliano Sánchez     1
# 43247    C. Fray Luis DePalacio/ Av. México     1
# 43248   Av. México /C. Bernardo de Balbuena     1
#
# [43249 rows x 3 columns]

# %%
MiBici2017.groupby(['Start_Name', 'End_Name']).size().reset_index(name = "size").sort_values("size", ascending = False).reset_index(drop=True)
# Out:
#                                  Start_Name  \
# 0                C. Juan Álvarez / C. Belén
# 1                C. Juan Álvarez / C. Belén
# 2       C. Miguel Blanco / C. Penitenciaria
# 3         Lopez Cotilla/ Marcos Castellanos
# 4            C. Marsella / C. López Cotilla
# ...                                     ...
# 33901   C. Bernardo de Balbuena /Av Hidalgo
# 33902   C. Bernardo de Balbuena /Av Hidalgo
# 33903        C. Paseo Don Bosco / C. Tonalá
# 33904     Av. Juárez / Av. 16 de Septiembre
# 33905   C. Rio Principal / Blvrd. García B.
#
#                                    End_Name  size
# 0                C. Juan Álvarez / C. Belén  2953
# 1       C. Monte Cáucaso / C. Sierra Nevada  2745
# 2       C. Miguel Blanco / C. Penitenciaria  2477
# 3         Lopez Cotilla/ Marcos Castellanos  2414
# 4         Lopez Cotilla/ Marcos Castellanos  2328
# ...                                     ...   ...
# 33901   Av Lázaro Cárdenas / Av San Ignacio     1
# 33902     Av. Aurelio Ortega / Av. Laureles     1
# 33903        C. Argentina / C. Pedro Moreno     1
# 33904           Av. Guadalupe / C. Boturini     1
# 33905    C. Constelación / Av. de los Arcos     1
#
# [33906 rows x 3 columns]
